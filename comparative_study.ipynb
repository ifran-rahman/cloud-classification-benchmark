# %%
import os
import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# ---------------------------------
# Reproducibility
# ---------------------------------
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


# ---------------------------------
# Tiny Efficient CNN (generic)
# ---------------------------------
class TinyEfficientCNN(nn.Module):
    """Small depthwise-separable CNN classifier."""

    def __init__(self, num_classes, in_channels=3):
        super().__init__()

        def conv_dw(inp, oup, stride=1):
            return nn.Sequential(
                nn.Conv2d(inp, inp, 3, stride, 1, groups=inp, bias=False),
                nn.BatchNorm2d(inp),
                nn.ReLU6(inplace=True),

                nn.Conv2d(inp, oup, 1, 1, 0, bias=False),
                nn.BatchNorm2d(oup),
                nn.ReLU6(inplace=True),
            )

        self.features = nn.Sequential(
            nn.Conv2d(in_channels, 32, 3, 2, 1, bias=False),
            nn.BatchNorm2d(32),
            nn.ReLU6(inplace=True),

            conv_dw(32, 64, 1),
            conv_dw(64, 128, 2),
            conv_dw(128, 256, 2),
            conv_dw(256, 512, 2),
            nn.AdaptiveAvgPool2d(1),
        )

        self.classifier = nn.Sequential(
            nn.Dropout(0.3),
            nn.Linear(512, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        return self.classifier(x)


# ---------------------------------
# Train / Test functions
# ---------------------------------
def train_epoch(model, loader, optimizer):
    model.train()
    total_loss = 0.0

    for data, target in loader:
        data, target = data.to(device), target.to(device)

        optimizer.zero_grad()
        output = model(data)
        loss = F.cross_entropy(output, target)
        loss.backward()
        optimizer.step()

        total_loss += loss.item() * data.size(0)

    return total_loss / len(loader.dataset)


@torch.no_grad()
def test_epoch(model, loader):
    model.eval()
    total_loss = 0.0
    correct = 0

    for data, target in loader:
        data, target = data.to(device), target.to(device)
        output = model(data)

        total_loss += F.cross_entropy(output, target, reduction='sum').item()
        pred = output.argmax(1)
        correct += (pred == target).sum().item()

    avg_loss = total_loss / len(loader.dataset)
    accuracy = 100.0 * correct / len(loader.dataset)
    return avg_loss, accuracy


# ---------------------------------
# Dataset + Loader
# ---------------------------------
def build_dataloaders(train_root, test_root, img_size=128, batch_size=128):
    # Separate transforms for train/test
    train_transform = transforms.Compose([
        transforms.Resize((img_size, img_size)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                           std=[0.229, 0.224, 0.225])
    ])
    
    test_transform = transforms.Compose([
        transforms.Resize((img_size, img_size)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                           std=[0.229, 0.224, 0.225])
    ])

    train_ds = datasets.ImageFolder(root=train_root, transform=train_transform)
    test_ds = datasets.ImageFolder(root=test_root, transform=test_transform)

    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True,
                              num_workers=2, pin_memory=True)
    test_loader = DataLoader(test_ds, batch_size=batch_size, shuffle=False,
                             num_workers=2, pin_memory=True)

    return train_ds, test_ds, train_loader, test_loader

# %% [markdown]
# Baseline Models Comparative Study

# %%
import torch
import torch.nn as nn
from torchvision import models


# ---------------------------------
# Create model given a name
# ---------------------------------
def build_model(name, num_classes):
    name = name.lower()

    if name == "tinycnn":
        return TinyEfficientCNN(num_classes=num_classes)

    elif name == "mobilenetv3_small":
        model = models.mobilenet_v3_small(pretrained=True)
        model.classifier[3] = nn.Linear(model.classifier[3].in_features, num_classes)
        return model

    elif name == "mobilenet_v2":
        model = models.mobilenet_v2(pretrained=True)
        model.classifier[1] = nn.Linear(model.classifier[1].in_features, num_classes)
        return model

    elif name == "efficientnet_b0":
        model = models.efficientnet_b0(pretrained=True)
        model.classifier[1] = nn.Linear(model.classifier[1].in_features, num_classes)
        return model

    elif name == "resnet18":
        model = models.resnet18(pretrained=True)
        model.fc = nn.Linear(model.fc.in_features, num_classes)
        return model

    elif name == "convnext_tiny":
        model = models.convnext_tiny(pretrained=True)
        model.classifier[2] = nn.Linear(model.classifier[2].in_features, num_classes)
        return model

    else:
        raise ValueError(f"Unknown model name: {name}")


def main():

    train_root = "/home/ifran/Projects_UBUNTU/emnss_dublin/clouds_train"
    test_root  = "/home/ifran/Projects_UBUNTU/emnss_dublin/clouds_test"

    num_epochs = 100
    batch_size = 256

    # -----------------------------
    # Load dataset ONCE
    # -----------------------------
    train_ds, test_ds, train_loader, test_loader = build_dataloaders(
        train_root, test_root, batch_size=batch_size
    )
    num_classes = len(train_ds.classes)

    # -----------------------------
    # Models to benchmark
    # -----------------------------
    model_names = [
        "convnext_tiny",        # ~28M params
        "resnet18",             # ~11.7M params
        "efficientnet_b0",      # ~5.3M params
        "mobilenet_v2",         # ~3.4M params
        "mobilenetv3_small",    # ~2.5M params
        "tinycnn",              # your custom smallest model
    ]


    # -----------------------------
    # Train each one in sequence
    # -----------------------------
    # Early stopping settings
    patience = 30
    wait = 0

    for name in model_names:
        print("\n" + "="*60)
        print(f"🔥 Training model: {name}")
        print("="*60)

        # Build model
        model = build_model(name, num_classes).to(device)

        # Optimizer & Scheduler
        optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
        scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.5)

        best_acc = 0.0
        wait = 0  # reset early-stopping counter

        if not os.path.exists('Checkpoints'):
            os.mkdir('Checkpoints')
        save_path = f"Checkpoints/best_{name}.pth"

        # -------------------------
        # Training loop + Early Stopping
        # -------------------------
        for epoch in range(num_epochs):
            train_loss = train_epoch(model, train_loader, optimizer)
            test_loss, test_acc = test_epoch(model, test_loader)
            scheduler.step()

            print(f"{name} | Epoch {epoch}: "
                f"Train={train_loss:.4f}  Test={test_loss:.4f}  Acc={test_acc:.2f}%")

            # Check for improvement
            if test_acc > best_acc:
                best_acc = test_acc
                torch.save(model.state_dict(), save_path)
                print(f"✔ Saved best ({best_acc:.2f}%) → {save_path}")
                wait = 0  # reset wait counter
            else:
                wait += 1

            # Trigger early stopping
            if wait >= patience:
                print(f"⛔ Early stopping triggered after {patience} epochs without improvement.")
                break

        print(f"🏁 Finished training {name}. Best Acc = {best_acc:.2f}%")

    print("\n🎉 All models trained successfully!")



if __name__ == "__main__":
    main()
# Out:
# ============================================================
# 🔥 Training model: convnext_tiny
# ============================================================
# /home/ifran/miniconda3/envs/pytorch/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/ifran/miniconda3/envs/pytorch/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ConvNeXt_Tiny_Weights.IMAGENET1K_V1`. You can also use `weights=ConvNeXt_Tiny_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# convnext_tiny | Epoch 0: Train=1.7921  Test=2.4181  Acc=14.20%
# ✔ Saved best (14.20%) → Checkpoints/best_convnext_tiny.pth
# convnext_tiny | Epoch 1: Train=2.2456  Test=1.7058  Acc=21.81%
# ✔ Saved best (21.81%) → Checkpoints/best_convnext_tiny.pth
# convnext_tiny | Epoch 2: Train=1.4901  Test=1.0552  Acc=66.26%
# ✔ Saved best (66.26%) → Checkpoints/best_convnext_tiny.pth
# convnext_tiny | Epoch 3: Train=0.9330  Test=1.1322  Acc=59.47%
# convnext_tiny | Epoch 4: Train=0.8495  Test=0.5283  Acc=82.10%
# ✔ Saved best (82.10%) → Checkpoints/best_convnext_tiny.pth
# convnext_tiny | Epoch 5: Train=0.5049  Test=0.3188  Acc=89.51%
# ✔ Saved best (89.51%) → Checkpoints/best_convnext_tiny.pth
# convnext_tiny | Epoch 6: Train=0.2691  Test=0.3834  Acc=85.19%
# convnext_tiny | Epoch 7: Train=0.2774  Test=0.2558  Acc=89.30%
# convnext_tiny | Epoch 8: Train=0.2175  Test=0.1807  Acc=93.42%
# ✔ Saved best (93.42%) → Checkpoints/best_convnext_tiny.pth
# convnext_tiny | Epoch 9: Train=0.1254  Test=0.3309  Acc=87.45%
# convnext_tiny | Epoch 10: Train=0.1288  Test=0.2531  Acc=90.95%
# convnext_tiny | Epoch 11: Train=0.0603  Test=0.2421  Acc=91.36%
# convnext_tiny | Epoch 12: Train=0.0567  Test=0.1985  Acc=92.80%
# convnext_tiny | Epoch 13: Train=0.0254  Test=0.1697  Acc=93.83%
# ✔ Saved best (93.83%) → Checkpoints/best_convnext_tiny.pth
# convnext_tiny | Epoch 14: Train=0.0118  Test=0.2305  Acc=92.80%
# convnext_tiny | Epoch 15: Train=0.0242  Test=0.2282  Acc=93.62%
# convnext_tiny | Epoch 16: Train=0.0133  Test=0.2198  Acc=92.80%
# convnext_tiny | Epoch 17: Train=0.0076  Test=0.2277  Acc=93.62%
# convnext_tiny | Epoch 18: Train=0.0045  Test=0.2801  Acc=92.80%
# convnext_tiny | Epoch 19: Train=0.0180  Test=0.2740  Acc=91.98%
# convnext_tiny | Epoch 20: Train=0.0100  Test=0.2979  Acc=92.39%
# convnext_tiny | Epoch 21: Train=0.0024  Test=0.2388  Acc=93.00%
# convnext_tiny | Epoch 22: Train=0.0015  Test=0.2452  Acc=93.62%
# convnext_tiny | Epoch 23: Train=0.0027  Test=0.2560  Acc=93.83%
# convnext_tiny | Epoch 24: Train=0.0009  Test=0.2681  Acc=93.42%
# convnext_tiny | Epoch 25: Train=0.0009  Test=0.2787  Acc=92.39%
# convnext_tiny | Epoch 26: Train=0.0009  Test=0.2857  Acc=92.59%
# convnext_tiny | Epoch 27: Train=0.0013  Test=0.2876  Acc=92.39%
# convnext_tiny | Epoch 28: Train=0.0009  Test=0.2840  Acc=92.59%
# convnext_tiny | Epoch 29: Train=0.0009  Test=0.2786  Acc=92.80%
# convnext_tiny | Epoch 30: Train=0.0008  Test=0.2737  Acc=93.21%
# convnext_tiny | Epoch 31: Train=0.0008  Test=0.2696  Acc=93.62%
# convnext_tiny | Epoch 32: Train=0.0005  Test=0.2675  Acc=93.62%
# convnext_tiny | Epoch 33: Train=0.0017  Test=0.2650  Acc=93.62%
# convnext_tiny | Epoch 34: Train=0.0004  Test=0.2803  Acc=93.83%
# convnext_tiny | Epoch 35: Train=0.0005  Test=0.3065  Acc=93.42%
# convnext_tiny | Epoch 36: Train=0.0010  Test=0.3100  Acc=93.62%
# convnext_tiny | Epoch 37: Train=0.0012  Test=0.2871  Acc=94.24%
# ✔ Saved best (94.24%) → Checkpoints/best_convnext_tiny.pth
# convnext_tiny | Epoch 38: Train=0.0008  Test=0.2572  Acc=94.24%
# convnext_tiny | Epoch 39: Train=0.0003  Test=0.2473  Acc=94.44%
# ✔ Saved best (94.44%) → Checkpoints/best_convnext_tiny.pth
# convnext_tiny | Epoch 40: Train=0.0003  Test=0.2477  Acc=93.83%
# convnext_tiny | Epoch 41: Train=0.0004  Test=0.2500  Acc=93.62%
# convnext_tiny | Epoch 42: Train=0.0003  Test=0.2533  Acc=93.62%
# convnext_tiny | Epoch 43: Train=0.0003  Test=0.2567  Acc=93.62%
# convnext_tiny | Epoch 44: Train=0.0007  Test=0.2605  Acc=93.83%
# convnext_tiny | Epoch 45: Train=0.0010  Test=0.2602  Acc=93.83%
# convnext_tiny | Epoch 46: Train=0.0003  Test=0.2593  Acc=93.83%
# convnext_tiny | Epoch 47: Train=0.0004  Test=0.2576  Acc=93.83%
# convnext_tiny | Epoch 48: Train=0.0003  Test=0.2560  Acc=93.42%
# convnext_tiny | Epoch 49: Train=0.0003  Test=0.2541  Acc=93.42%
# convnext_tiny | Epoch 50: Train=0.0003  Test=0.2525  Acc=93.83%
# convnext_tiny | Epoch 51: Train=0.0003  Test=0.2511  Acc=93.83%
# convnext_tiny | Epoch 52: Train=0.0003  Test=0.2501  Acc=93.83%
# convnext_tiny | Epoch 53: Train=0.0003  Test=0.2492  Acc=93.83%
# convnext_tiny | Epoch 54: Train=0.0003  Test=0.2485  Acc=93.83%
# convnext_tiny | Epoch 55: Train=0.0002  Test=0.2479  Acc=93.83%
# convnext_tiny | Epoch 56: Train=0.0002  Test=0.2475  Acc=94.03%
# convnext_tiny | Epoch 57: Train=0.0002  Test=0.2472  Acc=94.03%
# convnext_tiny | Epoch 58: Train=0.0002  Test=0.2470  Acc=94.03%
# convnext_tiny | Epoch 59: Train=0.0002  Test=0.2470  Acc=94.03%
# convnext_tiny | Epoch 60: Train=0.0003  Test=0.2471  Acc=94.03%
# convnext_tiny | Epoch 61: Train=0.0027  Test=0.2473  Acc=94.03%
# convnext_tiny | Epoch 62: Train=0.0002  Test=0.2479  Acc=94.03%
# convnext_tiny | Epoch 63: Train=0.0002  Test=0.2488  Acc=94.03%
# convnext_tiny | Epoch 64: Train=0.0004  Test=0.2491  Acc=94.03%
# convnext_tiny | Epoch 65: Train=0.0002  Test=0.2495  Acc=94.24%
# convnext_tiny | Epoch 66: Train=0.0002  Test=0.2499  Acc=94.24%
# convnext_tiny | Epoch 67: Train=0.0002  Test=0.2502  Acc=94.24%
# convnext_tiny | Epoch 68: Train=0.0002  Test=0.2505  Acc=94.24%
# convnext_tiny | Epoch 69: Train=0.0002  Test=0.2507  Acc=94.24%
# ⛔ Early stopping triggered after 30 epochs without improvement.
# 🏁 Finished training convnext_tiny. Best Acc = 94.44%
#
# ============================================================
# 🔥 Training model: resnet18
# ============================================================
# /home/ifran/miniconda3/envs/pytorch/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# resnet18 | Epoch 0: Train=1.3590  Test=1.0582  Acc=70.58%
# ✔ Saved best (70.58%) → Checkpoints/best_resnet18.pth
# resnet18 | Epoch 1: Train=0.2121  Test=1.2023  Acc=72.02%
# ✔ Saved best (72.02%) → Checkpoints/best_resnet18.pth
# resnet18 | Epoch 2: Train=0.0732  Test=1.8390  Acc=72.84%
# ✔ Saved best (72.84%) → Checkpoints/best_resnet18.pth
# resnet18 | Epoch 3: Train=0.0297  Test=1.6225  Acc=77.16%
# ✔ Saved best (77.16%) → Checkpoints/best_resnet18.pth
# resnet18 | Epoch 4: Train=0.0414  Test=1.7686  Acc=74.49%
# resnet18 | Epoch 5: Train=0.0349  Test=1.3623  Acc=75.72%
# resnet18 | Epoch 6: Train=0.0160  Test=1.1133  Acc=81.07%
# ✔ Saved best (81.07%) → Checkpoints/best_resnet18.pth
# resnet18 | Epoch 7: Train=0.0204  Test=0.9064  Acc=84.57%
# ✔ Saved best (84.57%) → Checkpoints/best_resnet18.pth
# resnet18 | Epoch 8: Train=0.0576  Test=0.5136  Acc=90.33%
# ✔ Saved best (90.33%) → Checkpoints/best_resnet18.pth
# resnet18 | Epoch 9: Train=0.0407  Test=0.7782  Acc=88.07%
# resnet18 | Epoch 10: Train=0.0316  Test=2.0481  Acc=77.37%
# resnet18 | Epoch 11: Train=0.0288  Test=1.8380  Acc=78.81%
# resnet18 | Epoch 12: Train=0.0147  Test=1.0831  Acc=79.84%
# resnet18 | Epoch 13: Train=0.0215  Test=0.8874  Acc=82.30%
# resnet18 | Epoch 14: Train=0.0288  Test=0.7851  Acc=82.92%
# resnet18 | Epoch 15: Train=0.0108  Test=0.8817  Acc=84.36%
# resnet18 | Epoch 16: Train=0.0120  Test=0.8695  Acc=84.36%
# resnet18 | Epoch 17: Train=0.0236  Test=0.7616  Acc=84.57%
# resnet18 | Epoch 18: Train=0.0215  Test=0.7351  Acc=85.80%
# resnet18 | Epoch 19: Train=0.0195  Test=0.7447  Acc=85.80%
# resnet18 | Epoch 20: Train=0.0140  Test=0.6383  Acc=87.86%
# resnet18 | Epoch 21: Train=0.0063  Test=0.5300  Acc=88.07%
# resnet18 | Epoch 22: Train=0.0026  Test=0.4696  Acc=89.71%
# resnet18 | Epoch 23: Train=0.0022  Test=0.4298  Acc=90.12%
# resnet18 | Epoch 24: Train=0.0014  Test=0.4089  Acc=90.95%
# ✔ Saved best (90.95%) → Checkpoints/best_resnet18.pth
# resnet18 | Epoch 25: Train=0.0026  Test=0.3860  Acc=91.15%
# ✔ Saved best (91.15%) → Checkpoints/best_resnet18.pth
# resnet18 | Epoch 26: Train=0.0011  Test=0.3674  Acc=91.56%
# ✔ Saved best (91.56%) → Checkpoints/best_resnet18.pth
# resnet18 | Epoch 27: Train=0.0084  Test=0.3334  Acc=91.98%
# ✔ Saved best (91.98%) → Checkpoints/best_resnet18.pth
# resnet18 | Epoch 28: Train=0.0011  Test=0.3148  Acc=91.98%
# resnet18 | Epoch 29: Train=0.0012  Test=0.3049  Acc=92.80%
# ✔ Saved best (92.80%) → Checkpoints/best_resnet18.pth
# resnet18 | Epoch 30: Train=0.0004  Test=0.3000  Acc=93.00%
# ✔ Saved best (93.00%) → Checkpoints/best_resnet18.pth
# resnet18 | Epoch 31: Train=0.0004  Test=0.2997  Acc=93.21%
# ✔ Saved best (93.21%) → Checkpoints/best_resnet18.pth
# resnet18 | Epoch 32: Train=0.0004  Test=0.2998  Acc=93.21%
# resnet18 | Epoch 33: Train=0.0003  Test=0.3008  Acc=93.62%
# ✔ Saved best (93.62%) → Checkpoints/best_resnet18.pth
# resnet18 | Epoch 34: Train=0.0011  Test=0.3063  Acc=93.42%
# resnet18 | Epoch 35: Train=0.0004  Test=0.3109  Acc=93.21%
# resnet18 | Epoch 36: Train=0.0003  Test=0.3131  Acc=93.21%
# resnet18 | Epoch 37: Train=0.0003  Test=0.3152  Acc=93.00%
# resnet18 | Epoch 38: Train=0.0002  Test=0.3159  Acc=92.59%
# resnet18 | Epoch 39: Train=0.0004  Test=0.3162  Acc=92.80%
# resnet18 | Epoch 40: Train=0.0002  Test=0.3162  Acc=93.00%
# resnet18 | Epoch 41: Train=0.0002  Test=0.3160  Acc=93.00%
# resnet18 | Epoch 42: Train=0.0002  Test=0.3159  Acc=92.80%
# resnet18 | Epoch 43: Train=0.0003  Test=0.3149  Acc=93.00%
# resnet18 | Epoch 44: Train=0.0002  Test=0.3156  Acc=93.00%
# resnet18 | Epoch 45: Train=0.0002  Test=0.3161  Acc=92.59%
# resnet18 | Epoch 46: Train=0.0002  Test=0.3164  Acc=92.59%
# resnet18 | Epoch 47: Train=0.0004  Test=0.3166  Acc=92.80%
# resnet18 | Epoch 48: Train=0.0002  Test=0.3156  Acc=93.42%
# resnet18 | Epoch 49: Train=0.0002  Test=0.3149  Acc=93.21%
# resnet18 | Epoch 50: Train=0.0002  Test=0.3121  Acc=93.21%
# resnet18 | Epoch 51: Train=0.0003  Test=0.3086  Acc=93.21%
# resnet18 | Epoch 52: Train=0.0001  Test=0.3071  Acc=93.21%
# resnet18 | Epoch 53: Train=0.0004  Test=0.3051  Acc=93.21%
# resnet18 | Epoch 54: Train=0.0002  Test=0.3036  Acc=93.21%
# resnet18 | Epoch 55: Train=0.0002  Test=0.3017  Acc=93.62%
# resnet18 | Epoch 56: Train=0.0001  Test=0.3010  Acc=93.42%
# resnet18 | Epoch 57: Train=0.0002  Test=0.3003  Acc=93.42%
# resnet18 | Epoch 58: Train=0.0002  Test=0.3010  Acc=93.42%
# resnet18 | Epoch 59: Train=0.0001  Test=0.3010  Acc=93.42%
# resnet18 | Epoch 60: Train=0.0001  Test=0.3000  Acc=93.42%
# resnet18 | Epoch 61: Train=0.0002  Test=0.2991  Acc=93.42%
# resnet18 | Epoch 62: Train=0.0001  Test=0.2988  Acc=93.42%
# resnet18 | Epoch 63: Train=0.0002  Test=0.2995  Acc=93.42%
# ⛔ Early stopping triggered after 30 epochs without improvement.
# 🏁 Finished training resnet18. Best Acc = 93.62%
#
# ============================================================
# 🔥 Training model: efficientnet_b0
# ============================================================
# /home/ifran/miniconda3/envs/pytorch/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# efficientnet_b0 | Epoch 0: Train=1.7604  Test=1.7490  Acc=39.71%
# ✔ Saved best (39.71%) → Checkpoints/best_efficientnet_b0.pth
# efficientnet_b0 | Epoch 1: Train=0.7718  Test=1.3383  Acc=49.79%
# ✔ Saved best (49.79%) → Checkpoints/best_efficientnet_b0.pth
# efficientnet_b0 | Epoch 2: Train=0.3033  Test=0.9530  Acc=70.78%
# ✔ Saved best (70.78%) → Checkpoints/best_efficientnet_b0.pth
# efficientnet_b0 | Epoch 3: Train=0.1257  Test=0.6427  Acc=83.54%
# ✔ Saved best (83.54%) → Checkpoints/best_efficientnet_b0.pth
# efficientnet_b0 | Epoch 4: Train=0.0630  Test=0.4963  Acc=88.48%
# ✔ Saved best (88.48%) → Checkpoints/best_efficientnet_b0.pth
# efficientnet_b0 | Epoch 5: Train=0.0353  Test=0.4038  Acc=90.53%
# ✔ Saved best (90.53%) → Checkpoints/best_efficientnet_b0.pth
# efficientnet_b0 | Epoch 6: Train=0.0187  Test=0.3625  Acc=91.77%
# ✔ Saved best (91.77%) → Checkpoints/best_efficientnet_b0.pth
# efficientnet_b0 | Epoch 7: Train=0.0075  Test=0.3448  Acc=92.80%
# ✔ Saved best (92.80%) → Checkpoints/best_efficientnet_b0.pth
# efficientnet_b0 | Epoch 8: Train=0.0075  Test=0.3342  Acc=92.80%
# efficientnet_b0 | Epoch 9: Train=0.0014  Test=0.3328  Acc=93.42%
# ✔ Saved best (93.42%) → Checkpoints/best_efficientnet_b0.pth
# efficientnet_b0 | Epoch 10: Train=0.0017  Test=0.3269  Acc=93.62%
# ✔ Saved best (93.62%) → Checkpoints/best_efficientnet_b0.pth
# efficientnet_b0 | Epoch 11: Train=0.0009  Test=0.3255  Acc=93.62%
# efficientnet_b0 | Epoch 12: Train=0.0011  Test=0.3131  Acc=94.65%
# ✔ Saved best (94.65%) → Checkpoints/best_efficientnet_b0.pth
# efficientnet_b0 | Epoch 13: Train=0.0003  Test=0.3048  Acc=94.65%
# efficientnet_b0 | Epoch 14: Train=0.0023  Test=0.2929  Acc=94.44%
# efficientnet_b0 | Epoch 15: Train=0.0015  Test=0.2744  Acc=95.06%
# ✔ Saved best (95.06%) → Checkpoints/best_efficientnet_b0.pth
# efficientnet_b0 | Epoch 16: Train=0.0023  Test=0.2621  Acc=95.68%
# ✔ Saved best (95.68%) → Checkpoints/best_efficientnet_b0.pth
# efficientnet_b0 | Epoch 17: Train=0.0016  Test=0.2570  Acc=95.88%
# ✔ Saved best (95.88%) → Checkpoints/best_efficientnet_b0.pth
# efficientnet_b0 | Epoch 18: Train=0.0002  Test=0.2626  Acc=95.88%
# efficientnet_b0 | Epoch 19: Train=0.0003  Test=0.2766  Acc=95.27%
# efficientnet_b0 | Epoch 20: Train=0.0003  Test=0.2824  Acc=94.65%
# efficientnet_b0 | Epoch 21: Train=0.0001  Test=0.2902  Acc=94.44%
# efficientnet_b0 | Epoch 22: Train=0.0001  Test=0.2975  Acc=94.24%
# efficientnet_b0 | Epoch 23: Train=0.0010  Test=0.3105  Acc=94.24%
# efficientnet_b0 | Epoch 24: Train=0.0006  Test=0.3197  Acc=94.24%
# efficientnet_b0 | Epoch 25: Train=0.0002  Test=0.3282  Acc=94.24%
# efficientnet_b0 | Epoch 26: Train=0.0004  Test=0.3322  Acc=93.83%
# efficientnet_b0 | Epoch 27: Train=0.0040  Test=0.3114  Acc=94.03%
# efficientnet_b0 | Epoch 28: Train=0.0001  Test=0.2936  Acc=94.24%
# efficientnet_b0 | Epoch 29: Train=0.0003  Test=0.2815  Acc=94.44%
# efficientnet_b0 | Epoch 30: Train=0.0003  Test=0.2749  Acc=94.65%
# efficientnet_b0 | Epoch 31: Train=0.0014  Test=0.2674  Acc=94.86%
# efficientnet_b0 | Epoch 32: Train=0.0002  Test=0.2634  Acc=95.06%
# efficientnet_b0 | Epoch 33: Train=0.0002  Test=0.2593  Acc=95.47%
# efficientnet_b0 | Epoch 34: Train=0.0005  Test=0.2591  Acc=95.06%
# efficientnet_b0 | Epoch 35: Train=0.0006  Test=0.2610  Acc=95.06%
# efficientnet_b0 | Epoch 36: Train=0.0010  Test=0.2614  Acc=95.06%
# efficientnet_b0 | Epoch 37: Train=0.0001  Test=0.2604  Acc=94.65%
# efficientnet_b0 | Epoch 38: Train=0.0008  Test=0.2617  Acc=94.44%
# efficientnet_b0 | Epoch 39: Train=0.0006  Test=0.2630  Acc=94.86%
# efficientnet_b0 | Epoch 40: Train=0.0001  Test=0.2620  Acc=94.65%
# efficientnet_b0 | Epoch 41: Train=0.0001  Test=0.2604  Acc=95.06%
# efficientnet_b0 | Epoch 42: Train=0.0047  Test=0.2483  Acc=95.47%
# efficientnet_b0 | Epoch 43: Train=0.0005  Test=0.2388  Acc=95.47%
# efficientnet_b0 | Epoch 44: Train=0.0001  Test=0.2278  Acc=95.47%
# efficientnet_b0 | Epoch 45: Train=0.0007  Test=0.2202  Acc=95.27%
# efficientnet_b0 | Epoch 46: Train=0.0001  Test=0.2177  Acc=95.68%
# efficientnet_b0 | Epoch 47: Train=0.0003  Test=0.2145  Acc=95.68%
# ⛔ Early stopping triggered after 30 epochs without improvement.
# 🏁 Finished training efficientnet_b0. Best Acc = 95.88%
#
# ============================================================
# 🔥 Training model: mobilenet_v2
# ============================================================
# /home/ifran/miniconda3/envs/pytorch/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V2_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# mobilenet_v2 | Epoch 0: Train=1.4555  Test=3.1053  Acc=22.63%
# ✔ Saved best (22.63%) → Checkpoints/best_mobilenet_v2.pth
# mobilenet_v2 | Epoch 1: Train=0.2548  Test=3.5626  Acc=30.86%
# ✔ Saved best (30.86%) → Checkpoints/best_mobilenet_v2.pth
# mobilenet_v2 | Epoch 2: Train=0.0814  Test=3.1691  Acc=45.88%
# ✔ Saved best (45.88%) → Checkpoints/best_mobilenet_v2.pth
# mobilenet_v2 | Epoch 3: Train=0.0645  Test=1.9868  Acc=64.61%
# ✔ Saved best (64.61%) → Checkpoints/best_mobilenet_v2.pth
# mobilenet_v2 | Epoch 4: Train=0.0674  Test=1.2558  Acc=76.54%
# ✔ Saved best (76.54%) → Checkpoints/best_mobilenet_v2.pth
# mobilenet_v2 | Epoch 5: Train=0.0173  Test=1.3465  Acc=74.07%
# mobilenet_v2 | Epoch 6: Train=0.0533  Test=0.6803  Acc=87.24%
# ✔ Saved best (87.24%) → Checkpoints/best_mobilenet_v2.pth
# mobilenet_v2 | Epoch 7: Train=0.0111  Test=0.6086  Acc=85.80%
# mobilenet_v2 | Epoch 8: Train=0.0540  Test=0.5899  Acc=87.24%
# mobilenet_v2 | Epoch 9: Train=0.0063  Test=0.6666  Acc=87.65%
# ✔ Saved best (87.65%) → Checkpoints/best_mobilenet_v2.pth
# mobilenet_v2 | Epoch 10: Train=0.0073  Test=0.6653  Acc=86.83%
# mobilenet_v2 | Epoch 11: Train=0.0127  Test=0.5906  Acc=87.65%
# mobilenet_v2 | Epoch 12: Train=0.0033  Test=0.6508  Acc=86.83%
# mobilenet_v2 | Epoch 13: Train=0.0171  Test=0.5937  Acc=87.65%
# mobilenet_v2 | Epoch 14: Train=0.0048  Test=0.4172  Acc=89.71%
# ✔ Saved best (89.71%) → Checkpoints/best_mobilenet_v2.pth
# mobilenet_v2 | Epoch 15: Train=0.0022  Test=0.3455  Acc=90.33%
# ✔ Saved best (90.33%) → Checkpoints/best_mobilenet_v2.pth
# mobilenet_v2 | Epoch 16: Train=0.0022  Test=0.3306  Acc=92.39%
# ✔ Saved best (92.39%) → Checkpoints/best_mobilenet_v2.pth
# mobilenet_v2 | Epoch 17: Train=0.0026  Test=0.3362  Acc=92.80%
# ✔ Saved best (92.80%) → Checkpoints/best_mobilenet_v2.pth
# mobilenet_v2 | Epoch 18: Train=0.0029  Test=0.3244  Acc=93.00%
# ✔ Saved best (93.00%) → Checkpoints/best_mobilenet_v2.pth
# mobilenet_v2 | Epoch 19: Train=0.0080  Test=0.3231  Acc=92.18%
# mobilenet_v2 | Epoch 20: Train=0.0012  Test=0.3280  Acc=92.80%
# mobilenet_v2 | Epoch 21: Train=0.0018  Test=0.3270  Acc=93.00%
# mobilenet_v2 | Epoch 22: Train=0.0011  Test=0.3224  Acc=92.59%
# mobilenet_v2 | Epoch 23: Train=0.0011  Test=0.3163  Acc=92.80%
# mobilenet_v2 | Epoch 24: Train=0.0008  Test=0.3065  Acc=92.59%
# mobilenet_v2 | Epoch 25: Train=0.0006  Test=0.2959  Acc=92.59%
# mobilenet_v2 | Epoch 26: Train=0.0005  Test=0.2916  Acc=93.21%
# ✔ Saved best (93.21%) → Checkpoints/best_mobilenet_v2.pth
# mobilenet_v2 | Epoch 27: Train=0.0008  Test=0.2858  Acc=93.00%
# mobilenet_v2 | Epoch 28: Train=0.0005  Test=0.2799  Acc=93.21%
# mobilenet_v2 | Epoch 29: Train=0.0004  Test=0.2754  Acc=93.00%
# mobilenet_v2 | Epoch 30: Train=0.0007  Test=0.2716  Acc=93.00%
# mobilenet_v2 | Epoch 31: Train=0.0003  Test=0.2728  Acc=93.00%
# mobilenet_v2 | Epoch 32: Train=0.0002  Test=0.2742  Acc=93.00%
# mobilenet_v2 | Epoch 33: Train=0.0001  Test=0.2734  Acc=93.21%
# mobilenet_v2 | Epoch 34: Train=0.0002  Test=0.2773  Acc=93.00%
# mobilenet_v2 | Epoch 35: Train=0.0003  Test=0.2759  Acc=92.80%
# mobilenet_v2 | Epoch 36: Train=0.0002  Test=0.2764  Acc=93.00%
# mobilenet_v2 | Epoch 37: Train=0.0003  Test=0.2755  Acc=93.00%
# mobilenet_v2 | Epoch 38: Train=0.0001  Test=0.2787  Acc=93.00%
# mobilenet_v2 | Epoch 39: Train=0.0001  Test=0.2782  Acc=93.42%
# ✔ Saved best (93.42%) → Checkpoints/best_mobilenet_v2.pth
# mobilenet_v2 | Epoch 40: Train=0.0001  Test=0.2779  Acc=93.42%
# mobilenet_v2 | Epoch 41: Train=0.0002  Test=0.2758  Acc=93.42%
# mobilenet_v2 | Epoch 42: Train=0.0001  Test=0.2753  Acc=93.42%
# mobilenet_v2 | Epoch 43: Train=0.0001  Test=0.2744  Acc=93.42%
# mobilenet_v2 | Epoch 44: Train=0.0002  Test=0.2746  Acc=93.42%
# mobilenet_v2 | Epoch 45: Train=0.0001  Test=0.2763  Acc=93.42%
# mobilenet_v2 | Epoch 46: Train=0.0001  Test=0.2747  Acc=93.42%
# mobilenet_v2 | Epoch 47: Train=0.0001  Test=0.2753  Acc=93.21%
# mobilenet_v2 | Epoch 48: Train=0.0001  Test=0.2752  Acc=93.21%
# mobilenet_v2 | Epoch 49: Train=0.0001  Test=0.2763  Acc=93.21%
# mobilenet_v2 | Epoch 50: Train=0.0003  Test=0.2760  Acc=93.21%
# mobilenet_v2 | Epoch 51: Train=0.0002  Test=0.2763  Acc=93.42%
# mobilenet_v2 | Epoch 52: Train=0.0001  Test=0.2742  Acc=93.42%
# mobilenet_v2 | Epoch 53: Train=0.0001  Test=0.2735  Acc=93.21%
# mobilenet_v2 | Epoch 54: Train=0.0002  Test=0.2732  Acc=93.21%
# mobilenet_v2 | Epoch 55: Train=0.0001  Test=0.2731  Acc=93.21%
# mobilenet_v2 | Epoch 56: Train=0.0001  Test=0.2727  Acc=93.21%
# mobilenet_v2 | Epoch 57: Train=0.0001  Test=0.2744  Acc=93.21%
# mobilenet_v2 | Epoch 58: Train=0.0001  Test=0.2747  Acc=93.21%
# mobilenet_v2 | Epoch 59: Train=0.0001  Test=0.2735  Acc=93.21%
# mobilenet_v2 | Epoch 60: Train=0.0004  Test=0.2760  Acc=93.62%
# ✔ Saved best (93.62%) → Checkpoints/best_mobilenet_v2.pth
# mobilenet_v2 | Epoch 61: Train=0.0001  Test=0.2774  Acc=93.21%
# mobilenet_v2 | Epoch 62: Train=0.0001  Test=0.2800  Acc=93.21%
# mobilenet_v2 | Epoch 63: Train=0.0001  Test=0.2819  Acc=93.42%
# mobilenet_v2 | Epoch 64: Train=0.0002  Test=0.2852  Acc=93.42%
# mobilenet_v2 | Epoch 65: Train=0.0001  Test=0.2858  Acc=93.42%
# mobilenet_v2 | Epoch 66: Train=0.0001  Test=0.2848  Acc=93.42%
# mobilenet_v2 | Epoch 67: Train=0.0001  Test=0.2854  Acc=93.42%
# mobilenet_v2 | Epoch 68: Train=0.0001  Test=0.2870  Acc=93.42%
# mobilenet_v2 | Epoch 69: Train=0.0001  Test=0.2869  Acc=93.42%
# mobilenet_v2 | Epoch 70: Train=0.0001  Test=0.2870  Acc=93.42%
# mobilenet_v2 | Epoch 71: Train=0.0001  Test=0.2863  Acc=93.42%
# mobilenet_v2 | Epoch 72: Train=0.0003  Test=0.2883  Acc=93.42%
# mobilenet_v2 | Epoch 73: Train=0.0001  Test=0.2865  Acc=93.42%
# mobilenet_v2 | Epoch 74: Train=0.0001  Test=0.2830  Acc=93.42%
# mobilenet_v2 | Epoch 75: Train=0.0001  Test=0.2812  Acc=93.42%
# mobilenet_v2 | Epoch 76: Train=0.0001  Test=0.2808  Acc=93.42%
# mobilenet_v2 | Epoch 77: Train=0.0001  Test=0.2809  Acc=93.42%
# mobilenet_v2 | Epoch 78: Train=0.0001  Test=0.2810  Acc=93.42%
# mobilenet_v2 | Epoch 79: Train=0.0001  Test=0.2802  Acc=93.42%
# mobilenet_v2 | Epoch 80: Train=0.0001  Test=0.2802  Acc=93.42%
# mobilenet_v2 | Epoch 81: Train=0.0001  Test=0.2803  Acc=93.42%
# mobilenet_v2 | Epoch 82: Train=0.0001  Test=0.2802  Acc=93.42%
# mobilenet_v2 | Epoch 83: Train=0.0001  Test=0.2797  Acc=93.42%
# mobilenet_v2 | Epoch 84: Train=0.0002  Test=0.2815  Acc=93.42%
# mobilenet_v2 | Epoch 85: Train=0.0001  Test=0.2798  Acc=93.42%
# mobilenet_v2 | Epoch 86: Train=0.0001  Test=0.2788  Acc=93.42%
# mobilenet_v2 | Epoch 87: Train=0.0001  Test=0.2770  Acc=93.42%
# mobilenet_v2 | Epoch 88: Train=0.0001  Test=0.2766  Acc=93.42%
# mobilenet_v2 | Epoch 89: Train=0.0001  Test=0.2763  Acc=93.42%
# mobilenet_v2 | Epoch 90: Train=0.0001  Test=0.2742  Acc=93.42%
# ⛔ Early stopping triggered after 30 epochs without improvement.
# 🏁 Finished training mobilenet_v2. Best Acc = 93.62%
#
# ============================================================
# 🔥 Training model: mobilenetv3_small
# ============================================================
# /home/ifran/miniconda3/envs/pytorch/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V3_Small_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V3_Small_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# mobilenetv3_small | Epoch 0: Train=1.7575  Test=1.6931  Acc=49.38%
# ✔ Saved best (49.38%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 1: Train=0.7740  Test=1.3488  Acc=61.73%
# ✔ Saved best (61.73%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 2: Train=0.3557  Test=1.0918  Acc=62.35%
# ✔ Saved best (62.35%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 3: Train=0.1591  Test=1.0418  Acc=61.11%
# mobilenetv3_small | Epoch 4: Train=0.0839  Test=1.1039  Acc=62.35%
# mobilenetv3_small | Epoch 5: Train=0.0424  Test=1.2435  Acc=61.73%
# mobilenetv3_small | Epoch 6: Train=0.0173  Test=1.3978  Acc=61.32%
# mobilenetv3_small | Epoch 7: Train=0.0107  Test=1.5200  Acc=61.32%
# mobilenetv3_small | Epoch 8: Train=0.0033  Test=1.5890  Acc=61.93%
# mobilenetv3_small | Epoch 9: Train=0.0029  Test=1.6417  Acc=62.76%
# ✔ Saved best (62.76%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 10: Train=0.0010  Test=1.6882  Acc=63.99%
# ✔ Saved best (63.99%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 11: Train=0.0013  Test=1.7382  Acc=65.02%
# ✔ Saved best (65.02%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 12: Train=0.0008  Test=1.7740  Acc=65.64%
# ✔ Saved best (65.64%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 13: Train=0.0002  Test=1.7943  Acc=66.05%
# ✔ Saved best (66.05%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 14: Train=0.0003  Test=1.7989  Acc=66.87%
# ✔ Saved best (66.87%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 15: Train=0.0002  Test=1.8020  Acc=67.49%
# ✔ Saved best (67.49%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 16: Train=0.0003  Test=1.7869  Acc=68.31%
# ✔ Saved best (68.31%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 17: Train=0.0002  Test=1.7669  Acc=68.72%
# ✔ Saved best (68.72%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 18: Train=0.0002  Test=1.7289  Acc=69.14%
# ✔ Saved best (69.14%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 19: Train=0.0001  Test=1.6948  Acc=70.37%
# ✔ Saved best (70.37%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 20: Train=0.0001  Test=1.6532  Acc=71.81%
# ✔ Saved best (71.81%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 21: Train=0.0002  Test=1.6127  Acc=72.43%
# ✔ Saved best (72.43%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 22: Train=0.0001  Test=1.5725  Acc=73.87%
# ✔ Saved best (73.87%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 23: Train=0.0001  Test=1.5352  Acc=75.72%
# ✔ Saved best (75.72%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 24: Train=0.0002  Test=1.4987  Acc=76.34%
# ✔ Saved best (76.34%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 25: Train=0.0003  Test=1.4679  Acc=76.75%
# ✔ Saved best (76.75%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 26: Train=0.0001  Test=1.4395  Acc=77.37%
# ✔ Saved best (77.37%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 27: Train=0.0007  Test=1.4013  Acc=78.19%
# ✔ Saved best (78.19%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 28: Train=0.0000  Test=1.3637  Acc=79.22%
# ✔ Saved best (79.22%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 29: Train=0.0000  Test=1.3303  Acc=79.84%
# ✔ Saved best (79.84%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 30: Train=0.0000  Test=1.2998  Acc=80.66%
# ✔ Saved best (80.66%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 31: Train=0.0000  Test=1.2700  Acc=81.07%
# ✔ Saved best (81.07%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 32: Train=0.0000  Test=1.2412  Acc=81.28%
# ✔ Saved best (81.28%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 33: Train=0.0000  Test=1.2129  Acc=81.48%
# ✔ Saved best (81.48%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 34: Train=0.0000  Test=1.1879  Acc=82.30%
# ✔ Saved best (82.30%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 35: Train=0.0000  Test=1.1633  Acc=82.30%
# mobilenetv3_small | Epoch 36: Train=0.0000  Test=1.1390  Acc=82.92%
# ✔ Saved best (82.92%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 37: Train=0.0000  Test=1.1153  Acc=82.92%
# mobilenetv3_small | Epoch 38: Train=0.0000  Test=1.0932  Acc=82.92%
# mobilenetv3_small | Epoch 39: Train=0.0001  Test=1.0722  Acc=82.92%
# mobilenetv3_small | Epoch 40: Train=0.0000  Test=1.0518  Acc=82.92%
# mobilenetv3_small | Epoch 41: Train=0.0001  Test=1.0326  Acc=83.13%
# ✔ Saved best (83.13%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 42: Train=0.0002  Test=1.0157  Acc=83.95%
# ✔ Saved best (83.95%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 43: Train=0.0000  Test=0.9996  Acc=84.36%
# ✔ Saved best (84.36%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 44: Train=0.0000  Test=0.9851  Acc=84.16%
# mobilenetv3_small | Epoch 45: Train=0.0000  Test=0.9718  Acc=84.57%
# ✔ Saved best (84.57%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 46: Train=0.0000  Test=0.9613  Acc=84.98%
# ✔ Saved best (84.98%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 47: Train=0.0000  Test=0.9522  Acc=85.39%
# ✔ Saved best (85.39%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 48: Train=0.0002  Test=0.9438  Acc=85.19%
# mobilenetv3_small | Epoch 49: Train=0.0000  Test=0.9377  Acc=84.98%
# mobilenetv3_small | Epoch 50: Train=0.0000  Test=0.9315  Acc=85.19%
# mobilenetv3_small | Epoch 51: Train=0.0000  Test=0.9263  Acc=85.60%
# ✔ Saved best (85.60%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 52: Train=0.0000  Test=0.9216  Acc=85.60%
# mobilenetv3_small | Epoch 53: Train=0.0000  Test=0.9170  Acc=85.60%
# mobilenetv3_small | Epoch 54: Train=0.0000  Test=0.9123  Acc=85.60%
# mobilenetv3_small | Epoch 55: Train=0.0001  Test=0.9064  Acc=85.60%
# mobilenetv3_small | Epoch 56: Train=0.0001  Test=0.9029  Acc=85.60%
# mobilenetv3_small | Epoch 57: Train=0.0000  Test=0.8978  Acc=85.80%
# ✔ Saved best (85.80%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 58: Train=0.0000  Test=0.8933  Acc=85.60%
# mobilenetv3_small | Epoch 59: Train=0.0000  Test=0.8878  Acc=85.60%
# mobilenetv3_small | Epoch 60: Train=0.0001  Test=0.8815  Acc=85.80%
# mobilenetv3_small | Epoch 61: Train=0.0000  Test=0.8744  Acc=85.80%
# mobilenetv3_small | Epoch 62: Train=0.0000  Test=0.8667  Acc=86.01%
# ✔ Saved best (86.01%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 63: Train=0.0001  Test=0.8589  Acc=85.80%
# mobilenetv3_small | Epoch 64: Train=0.0000  Test=0.8506  Acc=86.01%
# mobilenetv3_small | Epoch 65: Train=0.0001  Test=0.8426  Acc=86.01%
# mobilenetv3_small | Epoch 66: Train=0.0000  Test=0.8343  Acc=86.21%
# ✔ Saved best (86.21%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 67: Train=0.0000  Test=0.8261  Acc=86.21%
# mobilenetv3_small | Epoch 68: Train=0.0000  Test=0.8182  Acc=86.01%
# mobilenetv3_small | Epoch 69: Train=0.0000  Test=0.8115  Acc=86.21%
# mobilenetv3_small | Epoch 70: Train=0.0001  Test=0.8050  Acc=86.21%
# mobilenetv3_small | Epoch 71: Train=0.0001  Test=0.7992  Acc=86.21%
# mobilenetv3_small | Epoch 72: Train=0.0000  Test=0.7936  Acc=86.21%
# mobilenetv3_small | Epoch 73: Train=0.0002  Test=0.7898  Acc=86.63%
# ✔ Saved best (86.63%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 74: Train=0.0000  Test=0.7867  Acc=86.63%
# mobilenetv3_small | Epoch 75: Train=0.0000  Test=0.7831  Acc=86.63%
# mobilenetv3_small | Epoch 76: Train=0.0000  Test=0.7805  Acc=86.63%
# mobilenetv3_small | Epoch 77: Train=0.0000  Test=0.7774  Acc=86.83%
# ✔ Saved best (86.83%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 78: Train=0.0000  Test=0.7735  Acc=86.83%
# mobilenetv3_small | Epoch 79: Train=0.0000  Test=0.7697  Acc=86.83%
# mobilenetv3_small | Epoch 80: Train=0.0000  Test=0.7659  Acc=87.04%
# ✔ Saved best (87.04%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 81: Train=0.0000  Test=0.7621  Acc=87.04%
# mobilenetv3_small | Epoch 82: Train=0.0000  Test=0.7582  Acc=87.24%
# ✔ Saved best (87.24%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 83: Train=0.0000  Test=0.7544  Acc=87.24%
# mobilenetv3_small | Epoch 84: Train=0.0000  Test=0.7506  Acc=87.24%
# mobilenetv3_small | Epoch 85: Train=0.0000  Test=0.7473  Acc=87.24%
# mobilenetv3_small | Epoch 86: Train=0.0000  Test=0.7438  Acc=87.24%
# mobilenetv3_small | Epoch 87: Train=0.0000  Test=0.7408  Acc=87.45%
# ✔ Saved best (87.45%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 88: Train=0.0000  Test=0.7373  Acc=87.45%
# mobilenetv3_small | Epoch 89: Train=0.0001  Test=0.7339  Acc=87.65%
# ✔ Saved best (87.65%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 90: Train=0.0000  Test=0.7310  Acc=87.86%
# ✔ Saved best (87.86%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 91: Train=0.0000  Test=0.7278  Acc=87.86%
# mobilenetv3_small | Epoch 92: Train=0.0000  Test=0.7250  Acc=87.86%
# mobilenetv3_small | Epoch 93: Train=0.0001  Test=0.7222  Acc=88.07%
# ✔ Saved best (88.07%) → Checkpoints/best_mobilenetv3_small.pth
# mobilenetv3_small | Epoch 94: Train=0.0000  Test=0.7196  Acc=87.86%
# mobilenetv3_small | Epoch 95: Train=0.0000  Test=0.7162  Acc=87.86%
# mobilenetv3_small | Epoch 96: Train=0.0000  Test=0.7127  Acc=87.86%
# mobilenetv3_small | Epoch 97: Train=0.0000  Test=0.7102  Acc=87.65%
# mobilenetv3_small | Epoch 98: Train=0.0000  Test=0.7073  Acc=87.65%
# mobilenetv3_small | Epoch 99: Train=0.0000  Test=0.7049  Acc=87.65%
# 🏁 Finished training mobilenetv3_small. Best Acc = 88.07%
#
# ============================================================
# 🔥 Training model: tinycnn
# ============================================================
# tinycnn | Epoch 0: Train=1.8172  Test=1.9376  Acc=24.69%
# ✔ Saved best (24.69%) → Checkpoints/best_tinycnn.pth
# tinycnn | Epoch 1: Train=1.4847  Test=1.9394  Acc=8.23%
# tinycnn | Epoch 2: Train=1.2491  Test=1.9485  Acc=13.17%
# tinycnn | Epoch 3: Train=1.1010  Test=1.9765  Acc=13.17%
# tinycnn | Epoch 4: Train=0.9751  Test=2.0327  Acc=13.17%
# tinycnn | Epoch 5: Train=0.8982  Test=2.1277  Acc=13.17%
# tinycnn | Epoch 6: Train=0.8314  Test=2.2635  Acc=15.84%
# tinycnn | Epoch 7: Train=0.7673  Test=2.4271  Acc=12.96%
# tinycnn | Epoch 8: Train=0.7245  Test=2.6159  Acc=12.35%
# tinycnn | Epoch 9: Train=0.6780  Test=2.8141  Acc=13.37%
# tinycnn | Epoch 10: Train=0.6232  Test=3.0022  Acc=14.81%
# tinycnn | Epoch 11: Train=0.5965  Test=3.1755  Acc=16.87%
# tinycnn | Epoch 12: Train=0.5604  Test=3.3178  Acc=18.11%
# tinycnn | Epoch 13: Train=0.5307  Test=3.4312  Acc=18.93%
# tinycnn | Epoch 14: Train=0.4933  Test=3.4850  Acc=19.14%
# tinycnn | Epoch 15: Train=0.4583  Test=3.3915  Acc=19.75%
# tinycnn | Epoch 16: Train=0.4126  Test=3.1305  Acc=20.58%
# tinycnn | Epoch 17: Train=0.3885  Test=2.7505  Acc=24.69%
# tinycnn | Epoch 18: Train=0.3659  Test=2.2924  Acc=30.45%
# ✔ Saved best (30.45%) → Checkpoints/best_tinycnn.pth
# tinycnn | Epoch 19: Train=0.3486  Test=1.8353  Acc=38.48%
# ✔ Saved best (38.48%) → Checkpoints/best_tinycnn.pth
# tinycnn | Epoch 20: Train=0.3305  Test=1.4504  Acc=46.30%
# ✔ Saved best (46.30%) → Checkpoints/best_tinycnn.pth
# tinycnn | Epoch 21: Train=0.2971  Test=1.1557  Acc=55.97%
# ✔ Saved best (55.97%) → Checkpoints/best_tinycnn.pth
# tinycnn | Epoch 22: Train=0.2899  Test=0.9401  Acc=64.61%
# ✔ Saved best (64.61%) → Checkpoints/best_tinycnn.pth
# tinycnn | Epoch 23: Train=0.2648  Test=0.7826  Acc=70.78%
# ✔ Saved best (70.78%) → Checkpoints/best_tinycnn.pth
# tinycnn | Epoch 24: Train=0.2710  Test=0.6622  Acc=75.93%
# ✔ Saved best (75.93%) → Checkpoints/best_tinycnn.pth
# tinycnn | Epoch 25: Train=0.2618  Test=0.5854  Acc=80.04%
# ✔ Saved best (80.04%) → Checkpoints/best_tinycnn.pth
# tinycnn | Epoch 26: Train=0.2369  Test=0.5397  Acc=80.04%
# tinycnn | Epoch 27: Train=0.2223  Test=0.5164  Acc=81.48%
# ✔ Saved best (81.48%) → Checkpoints/best_tinycnn.pth
# tinycnn | Epoch 28: Train=0.2309  Test=0.5083  Acc=82.51%
# ✔ Saved best (82.51%) → Checkpoints/best_tinycnn.pth
# tinycnn | Epoch 29: Train=0.2034  Test=0.4984  Acc=81.89%
# tinycnn | Epoch 30: Train=0.2092  Test=0.4877  Acc=81.28%
# tinycnn | Epoch 31: Train=0.1882  Test=0.4763  Acc=81.69%
# tinycnn | Epoch 32: Train=0.1813  Test=0.4684  Acc=82.51%
# tinycnn | Epoch 33: Train=0.1704  Test=0.4669  Acc=81.89%
# tinycnn | Epoch 34: Train=0.1723  Test=0.4741  Acc=81.69%
# tinycnn | Epoch 35: Train=0.1594  Test=0.4738  Acc=81.28%
# tinycnn | Epoch 36: Train=0.1442  Test=0.4691  Acc=82.30%
# tinycnn | Epoch 37: Train=0.1359  Test=0.4667  Acc=82.10%
# tinycnn | Epoch 38: Train=0.1443  Test=0.4636  Acc=82.51%
# tinycnn | Epoch 39: Train=0.1276  Test=0.4630  Acc=83.13%
# ✔ Saved best (83.13%) → Checkpoints/best_tinycnn.pth
# tinycnn | Epoch 40: Train=0.1292  Test=0.4623  Acc=83.13%
# tinycnn | Epoch 41: Train=0.1122  Test=0.4604  Acc=83.13%
# tinycnn | Epoch 42: Train=0.1192  Test=0.4550  Acc=82.51%
# tinycnn | Epoch 43: Train=0.1046  Test=0.4523  Acc=82.92%
# tinycnn | Epoch 44: Train=0.1151  Test=0.4513  Acc=82.72%
# tinycnn | Epoch 45: Train=0.1149  Test=0.4476  Acc=83.33%
# ✔ Saved best (83.33%) → Checkpoints/best_tinycnn.pth
# tinycnn | Epoch 46: Train=0.1060  Test=0.4481  Acc=83.13%
# tinycnn | Epoch 47: Train=0.1011  Test=0.4497  Acc=82.51%
# tinycnn | Epoch 48: Train=0.1011  Test=0.4512  Acc=82.10%
# tinycnn | Epoch 49: Train=0.0977  Test=0.4519  Acc=82.72%
# tinycnn | Epoch 50: Train=0.1026  Test=0.4516  Acc=82.92%
# tinycnn | Epoch 51: Train=0.0967  Test=0.4500  Acc=83.13%
# tinycnn | Epoch 52: Train=0.0930  Test=0.4490  Acc=83.13%
# tinycnn | Epoch 53: Train=0.0840  Test=0.4470  Acc=83.33%
# tinycnn | Epoch 54: Train=0.0857  Test=0.4457  Acc=83.33%
# tinycnn | Epoch 55: Train=0.0825  Test=0.4444  Acc=83.33%
# tinycnn | Epoch 56: Train=0.0858  Test=0.4463  Acc=83.54%
# ✔ Saved best (83.54%) → Checkpoints/best_tinycnn.pth
# tinycnn | Epoch 57: Train=0.0808  Test=0.4463  Acc=83.33%
# tinycnn | Epoch 58: Train=0.0795  Test=0.4448  Acc=83.13%
# tinycnn | Epoch 59: Train=0.0723  Test=0.4429  Acc=83.13%
# tinycnn | Epoch 60: Train=0.0781  Test=0.4417  Acc=83.54%
# tinycnn | Epoch 61: Train=0.0732  Test=0.4410  Acc=83.74%
# ✔ Saved best (83.74%) → Checkpoints/best_tinycnn.pth
# tinycnn | Epoch 62: Train=0.0660  Test=0.4401  Acc=83.74%
# tinycnn | Epoch 63: Train=0.0735  Test=0.4409  Acc=83.54%
# tinycnn | Epoch 64: Train=0.0749  Test=0.4417  Acc=83.54%
# tinycnn | Epoch 65: Train=0.0677  Test=0.4425  Acc=83.33%
# tinycnn | Epoch 66: Train=0.0654  Test=0.4418  Acc=83.33%
# tinycnn | Epoch 67: Train=0.0698  Test=0.4430  Acc=82.92%
# tinycnn | Epoch 68: Train=0.0670  Test=0.4443  Acc=83.13%
# tinycnn | Epoch 69: Train=0.0588  Test=0.4455  Acc=83.13%
# tinycnn | Epoch 70: Train=0.0679  Test=0.4460  Acc=83.33%
# tinycnn | Epoch 71: Train=0.0641  Test=0.4456  Acc=83.54%
# tinycnn | Epoch 72: Train=0.0632  Test=0.4444  Acc=83.54%
# tinycnn | Epoch 73: Train=0.0614  Test=0.4435  Acc=83.74%
# tinycnn | Epoch 74: Train=0.0574  Test=0.4433  Acc=83.54%
# tinycnn | Epoch 75: Train=0.0563  Test=0.4427  Acc=83.54%
# tinycnn | Epoch 76: Train=0.0594  Test=0.4417  Acc=83.33%
# tinycnn | Epoch 77: Train=0.0572  Test=0.4413  Acc=83.54%
# tinycnn | Epoch 78: Train=0.0752  Test=0.4424  Acc=83.33%
# tinycnn | Epoch 79: Train=0.0590  Test=0.4414  Acc=83.54%
# tinycnn | Epoch 80: Train=0.0552  Test=0.4408  Acc=83.74%
# tinycnn | Epoch 81: Train=0.0573  Test=0.4391  Acc=83.54%
# tinycnn | Epoch 82: Train=0.0568  Test=0.4388  Acc=83.74%
# tinycnn | Epoch 83: Train=0.0578  Test=0.4384  Acc=83.74%
# tinycnn | Epoch 84: Train=0.0526  Test=0.4379  Acc=83.74%
# tinycnn | Epoch 85: Train=0.0601  Test=0.4381  Acc=83.74%
# tinycnn | Epoch 86: Train=0.0665  Test=0.4394  Acc=83.74%
# tinycnn | Epoch 87: Train=0.0537  Test=0.4394  Acc=83.95%
# ✔ Saved best (83.95%) → Checkpoints/best_tinycnn.pth
# tinycnn | Epoch 88: Train=0.0563  Test=0.4396  Acc=83.74%
# tinycnn | Epoch 89: Train=0.0574  Test=0.4395  Acc=83.95%
# tinycnn | Epoch 90: Train=0.0543  Test=0.4396  Acc=83.74%
# tinycnn | Epoch 91: Train=0.0510  Test=0.4403  Acc=83.74%
# tinycnn | Epoch 92: Train=0.0534  Test=0.4408  Acc=83.74%
# tinycnn | Epoch 93: Train=0.0508  Test=0.4412  Acc=83.95%
# tinycnn | Epoch 94: Train=0.0496  Test=0.4418  Acc=83.74%
# tinycnn | Epoch 95: Train=0.0500  Test=0.4418  Acc=83.74%
# tinycnn | Epoch 96: Train=0.0526  Test=0.4423  Acc=83.74%
# tinycnn | Epoch 97: Train=0.0475  Test=0.4433  Acc=83.74%
# tinycnn | Epoch 98: Train=0.0490  Test=0.4435  Acc=83.54%
# tinycnn | Epoch 99: Train=0.0504  Test=0.4431  Acc=83.74%
# 🏁 Finished training tinycnn. Best Acc = 83.95%
#
# 🎉 All models trained successfully!

# %% [markdown]
# Efficiency-Accuracy Results

# %%
import torch
import torch.nn as nn
from torchvision import models, transforms, datasets
from torch.utils.data import DataLoader
from ptflops import get_model_complexity_info
import time


device_gpu = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device_cpu = torch.device("cpu")


# -------------------------------------------------
# Load models (same as training)
# -------------------------------------------------
def build_model(name, num_classes):
    name = name.lower()

    if name == "tinycnn":
        return TinyEfficientCNN(num_classes=num_classes)

    elif name == "mobilenetv3_small":
        model = models.mobilenet_v3_small(pretrained=False)
        model.classifier[3] = nn.Linear(model.classifier[3].in_features, num_classes)
        return model

    elif name == "mobilenet_v2":
        model = models.mobilenet_v2(pretrained=False)
        model.classifier[1] = nn.Linear(model.classifier[1].in_features, num_classes)
        return model

    elif name == "efficientnet_b0":
        model = models.efficientnet_b0(pretrained=False)
        model.classifier[1] = nn.Linear(model.classifier[1].in_features, num_classes)
        return model

    elif name == "resnet18":
        model = models.resnet18(pretrained=False)
        model.fc = nn.Linear(model.fc.in_features, num_classes)
        return model

    elif name == "convnext_tiny":
        model = models.convnext_tiny(pretrained=False)
        model.classifier[2] = nn.Linear(model.classifier[2].in_features, num_classes)
        return model

    else:
        raise ValueError("Unknown model: " + name)


# -------------------------------------------------
# Accuracy Evaluation
# -------------------------------------------------
@torch.no_grad()
def compute_accuracy(model, dataloader, device):
    model.eval().to(device)
    correct, total = 0, 0

    for x, y in dataloader:
        x, y = x.to(device), y.to(device)
        pred = model(x).argmax(1)
        correct += (pred == y).sum().item()
        total += y.size(0)

    return 100 * correct / total


# -------------------------------------------------
# Latency measurement
# -------------------------------------------------
def measure_latency(model, device, input_shape=(1, 3, 128, 128), runs=50):
    model.to(device).eval()

    dummy = torch.randn(*input_shape).to(device)

    # Warm-up
    for _ in range(10):
        _ = model(dummy)

    # Timed runs
    start = time.time()
    for _ in range(runs):
        _ = model(dummy)
    end = time.time()

    return (end - start) / runs  # seconds per inference


# -------------------------------------------------
# Main Evaluation
# -------------------------------------------------
def main():

    # --------------------------
    # Dataset
    # --------------------------
    test_root = "/home/ifran/Projects_UBUNTU/emnss_dublin/clouds_test"

    transform = transforms.Compose([
        transforms.Resize((128, 128)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                           std=[0.229, 0.224, 0.225])
    ])

    test_ds = datasets.ImageFolder(test_root, transform=transform)
    test_loader = DataLoader(test_ds, batch_size=64, shuffle=False)

    num_classes = len(test_ds.classes)

    # --------------------------
    # Models to evaluate
    # --------------------------
    model_names = [
        "tinycnn",
        "mobilenetv3_small",
        "mobilenet_v2",
        "efficientnet_b0",
        "resnet18",
        "convnext_tiny",
    ]

    # --------------------------
    # Loop over all models
    # --------------------------
    for name in model_names:

        print("\n" + "="*60)
        print(f" Evaluating Model: {name}")
        print("="*60)

        # Build + load checkpoint
        model = build_model(name, num_classes)
        ckpt = f"Checkpoints/best_{name}.pth"
        model.load_state_dict(torch.load(ckpt, map_location="cpu"))

        # ------------------------------
        # Params
        # ------------------------------
        num_params = sum(p.numel() for p in model.parameters())
        print(f"Parameters: {num_params/1e6:.3f} M")

        # ------------------------------
        # FLOPs
        # ------------------------------
        with torch.cuda.device(0):
            macs, params = get_model_complexity_info(
                model, (3, 128, 128),
                as_strings=False,
                print_per_layer_stat=False
            )
        print(f"FLOPs: {macs/1e6:.2f} MFLOPs")

        # ------------------------------
        # Accuracy (GPU if available)
        # ------------------------------
        acc_gpu = compute_accuracy(model, test_loader, device_gpu)
        print(f"Accuracy (GPU): {acc_gpu:.2f}%")

        # ------------------------------
        # Latency
        # ------------------------------
        lat_gpu = measure_latency(model, device_gpu)
        lat_cpu = measure_latency(model, device_cpu)

        print(f"Latency (GPU): {lat_gpu*1000:.2f} ms")
        print(f"Latency (CPU – edge-like): {lat_cpu*1000:.2f} ms")

        print("="*60)


if __name__ == "__main__":
    main()
# Out:
# ============================================================
#  Evaluating Model: tinycnn
# ============================================================
# Parameters: 0.186 M
# FLOPs: 41.98 MFLOPs
# /tmp/ipykernel_26317/3554483587.py:135: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(ckpt, map_location="cpu"))
# Accuracy (GPU): 83.95%
# Latency (GPU): 1.52 ms
# Latency (CPU – edge-like): 2.18 ms
# ============================================================
#
# ============================================================
#  Evaluating Model: mobilenetv3_small
# ============================================================
# Parameters: 1.525 M
# FLOPs: 20.27 MFLOPs
# /home/ifran/miniconda3/envs/pytorch/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/ifran/miniconda3/envs/pytorch/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Accuracy (GPU): 88.07%
# Latency (GPU): 5.73 ms
# Latency (CPU – edge-like): 3.74 ms
# ============================================================
#
# ============================================================
#  Evaluating Model: mobilenet_v2
# ============================================================
# Parameters: 2.233 M
# FLOPs: 104.18 MFLOPs
# Accuracy (GPU): 93.62%
# Latency (GPU): 6.11 ms
# Latency (CPU – edge-like): 7.75 ms
# ============================================================
#
# ============================================================
#  Evaluating Model: efficientnet_b0
# ============================================================
# Parameters: 4.017 M
# FLOPs: 133.96 MFLOPs
# Accuracy (GPU): 95.88%
# Latency (GPU): 9.35 ms
# Latency (CPU – edge-like): 11.72 ms
# ============================================================
#
# ============================================================
#  Evaluating Model: resnet18
# ============================================================
# Parameters: 11.180 M
# FLOPs: 595.86 MFLOPs
# Accuracy (GPU): 93.62%
# Latency (GPU): 2.62 ms
# Latency (CPU – edge-like): 7.57 ms
# ============================================================
#
# ============================================================
#  Evaluating Model: convnext_tiny
# ============================================================
# Parameters: 27.826 M
# FLOPs: 1465.34 MFLOPs
# Accuracy (GPU): 94.44%
# Latency (GPU): 5.70 ms
# Latency (CPU – edge-like): 18.91 ms
# ============================================================

# %% [markdown]
# Self-Distillation

# %%
import torch
import torch.nn as nn
from torchvision import models

# --------------------------------------------------------
# Simple Knowledge Distillation Loss
# --------------------------------------------------------
def kd_loss(student_logits, teacher_logits, T=4.0, alpha=0.5):
    """
    student_logits: raw outputs of student
    teacher_logits: raw outputs of teacher
    """
    KD = nn.KLDivLoss(reduction="batchmean")
    log_p_s = nn.functional.log_softmax(student_logits / T, dim=1)
    p_t = nn.functional.softmax(teacher_logits / T, dim=1)

    soft_loss = KD(log_p_s, p_t) * (T * T)
    return alpha * soft_loss


# --------------------------------------------------------
# Build model (unchanged)
# --------------------------------------------------------
def build_model(name, num_classes):
    name = name.lower()

    if name == "tinycnn":
        return TinyEfficientCNN(num_classes=num_classes)

    elif name == "mobilenetv3_small":
        model = models.mobilenet_v3_small(pretrained=True)
        model.classifier[3] = nn.Linear(model.classifier[3].in_features, num_classes)
        return model

    elif name == "mobilenet_v2":
        model = models.mobilenet_v2(pretrained=True)
        model.classifier[1] = nn.Linear(model.classifier[1].in_features, num_classes)
        return model

    elif name == "efficientnet_b0":
        model = models.efficientnet_b0(pretrained=True)
        model.classifier[1] = nn.Linear(model.classifier[1].in_features, num_classes)
        return model

    elif name == "resnet18":
        model = models.resnet18(pretrained=True)
        model.fc = nn.Linear(model.fc.in_features, num_classes)
        return model

    elif name == "convnext_tiny":
        model = models.convnext_tiny(pretrained=True)
        model.classifier[2] = nn.Linear(model.classifier[2].in_features, num_classes)
        return model

    else:
        raise ValueError(f"Unknown model name: {name}")


# =========================================================
# Main
# =========================================================
def main():

    train_root = "/home/ifran/Projects_UBUNTU/emnss_dublin/clouds_train"
    test_root  = "/home/ifran/Projects_UBUNTU/emnss_dublin/clouds_test"

    num_epochs = 100
    batch_size = 256
    patience = 30

    # -----------------------------
    # Load dataset ONCE
    # -----------------------------
    train_ds, test_ds, train_loader, test_loader = build_dataloaders(
        train_root, test_root, batch_size=batch_size
    )
    num_classes = len(train_ds.classes)

    # -----------------------------
    # Models to benchmark
    # -----------------------------
    model_names = [
        "convnext_tiny",
        "resnet18",
        "efficientnet_b0",
        "mobilenet_v2",
        "mobilenetv3_small",
        "tinycnn",
    ]


    # =====================================================
    # Part 1 — For each model: TRAIN teacher model
    # =====================================================
    for name in model_names:

        print("\n" + "="*70)
        print(f"🔥 Training TEACHER model: {name}")
        print("="*70)

        teacher = build_model(name, num_classes).to(device)

        optimizer = torch.optim.Adam(teacher.parameters(), lr=1e-3)
        scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.5)

        best_acc = 0.0
        wait = 0

        if not os.path.exists('Checkpoints'):
            os.mkdir('Checkpoints')
        save_path = f"Checkpoints/best_{name}.pth"

        for epoch in range(num_epochs):
            train_loss = train_epoch(teacher, train_loader, optimizer)
            test_loss, test_acc = test_epoch(teacher, test_loader)
            scheduler.step()

            print(f"{name} Teacher | Epoch {epoch} "
                  f"Train={train_loss:.4f}  Test={test_loss:.4f}  Acc={test_acc:.2f}%")

            if test_acc > best_acc:
                best_acc = test_acc
                torch.save(teacher.state_dict(), save_path)
                print(f"✔ Saved TEACHER checkpoint ({best_acc:.2f}%)")
                wait = 0
            else:
                wait += 1

            if wait >= patience:
                print("⛔ Early stopping (teacher)")
                break

        print(f"🏁 Finished TEACHER for {name}. Best Acc={best_acc:.2f}%")



    # =====================================================
    # Part 2 — For each model: TRAIN student with KD
    # =====================================================
    for name in model_names:

        print("\n" + "="*70)
        print(f"🎓 Training STUDENT model with KD: {name}")
        print("="*70)

        # Load teacher
        teacher = build_model(name, num_classes).to(device)
        teacher.load_state_dict(torch.load(f"Checkpoints/best_{name}.pth"))
        teacher.eval()

        # Build fresh student
        student = build_model(name, num_classes).to(device)

        optimizer = torch.optim.Adam(student.parameters(), lr=1e-3)
        scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=20, gamma=0.5)

        best_acc = 0.0
        wait = 0

        save_path = f"Checkpoints/student_{name}.pth"

        for epoch in range(num_epochs):
            student.train()

            total_loss = 0
            for imgs, labels in train_loader:
                imgs, labels = imgs.to(device), labels.to(device)

                optimizer.zero_grad()

                # Forward
                s_logits = student(imgs)
                with torch.no_grad():
                    t_logits = teacher(imgs)

                # Combined KD + CE loss
                ce_loss = nn.CrossEntropyLoss()(s_logits, labels)
                distill = kd_loss(s_logits, t_logits)

                loss = ce_loss + distill

                loss.backward()
                optimizer.step()

                total_loss += loss.item()

            # Evaluate student
            test_loss, test_acc = test_epoch(student, test_loader)
            scheduler.step()

            print(f"{name} Student | Epoch {epoch}: "
                  f"TrainLoss={total_loss/len(train_loader):.4f}  Acc={test_acc:.2f}%")

            if test_acc > best_acc:
                best_acc = test_acc
                torch.save(student.state_dict(), save_path)
                print(f"✔ Saved STUDENT checkpoint ({best_acc:.2f}%)")
                wait = 0
            else:
                wait += 1

            if wait >= patience:
                print("⛔ Early stopping (student)")
                break

        print(f"🏁 Finished STUDENT for {name}. Best Acc={best_acc:.2f}%")


    print("\n🎉 All teacher–student KD training done!")


# --------------------------------------------------------
if __name__ == "__main__":
    main()
# Out:
# ======================================================================
# 🔥 Training TEACHER model: convnext_tiny
# ======================================================================
# /home/ifran/miniconda3/envs/pytorch/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/ifran/miniconda3/envs/pytorch/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ConvNeXt_Tiny_Weights.IMAGENET1K_V1`. You can also use `weights=ConvNeXt_Tiny_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# convnext_tiny Teacher | Epoch 0 Train=1.7921  Test=2.4181  Acc=14.20%
# ✔ Saved TEACHER checkpoint (14.20%)
# convnext_tiny Teacher | Epoch 1 Train=2.2456  Test=1.7058  Acc=21.81%
# ✔ Saved TEACHER checkpoint (21.81%)
# convnext_tiny Teacher | Epoch 2 Train=1.4901  Test=1.0552  Acc=66.26%
# ✔ Saved TEACHER checkpoint (66.26%)
# convnext_tiny Teacher | Epoch 3 Train=0.9330  Test=1.1322  Acc=59.47%
# convnext_tiny Teacher | Epoch 4 Train=0.8495  Test=0.5283  Acc=82.10%
# ✔ Saved TEACHER checkpoint (82.10%)
# convnext_tiny Teacher | Epoch 5 Train=0.5049  Test=0.3188  Acc=89.51%
# ✔ Saved TEACHER checkpoint (89.51%)
# convnext_tiny Teacher | Epoch 6 Train=0.2691  Test=0.3834  Acc=85.19%
# convnext_tiny Teacher | Epoch 7 Train=0.2774  Test=0.2558  Acc=89.30%
# convnext_tiny Teacher | Epoch 8 Train=0.2175  Test=0.1807  Acc=93.42%
# ✔ Saved TEACHER checkpoint (93.42%)
# convnext_tiny Teacher | Epoch 9 Train=0.1254  Test=0.3309  Acc=87.45%
# convnext_tiny Teacher | Epoch 10 Train=0.1288  Test=0.2531  Acc=90.95%
# convnext_tiny Teacher | Epoch 11 Train=0.0603  Test=0.2421  Acc=91.36%
# convnext_tiny Teacher | Epoch 12 Train=0.0567  Test=0.1985  Acc=92.80%
# convnext_tiny Teacher | Epoch 13 Train=0.0254  Test=0.1697  Acc=93.83%
# ✔ Saved TEACHER checkpoint (93.83%)
# convnext_tiny Teacher | Epoch 14 Train=0.0118  Test=0.2305  Acc=92.80%
# convnext_tiny Teacher | Epoch 15 Train=0.0242  Test=0.2282  Acc=93.62%
# convnext_tiny Teacher | Epoch 16 Train=0.0133  Test=0.2198  Acc=92.80%
# convnext_tiny Teacher | Epoch 17 Train=0.0076  Test=0.2277  Acc=93.62%
# convnext_tiny Teacher | Epoch 18 Train=0.0045  Test=0.2801  Acc=92.80%
# convnext_tiny Teacher | Epoch 19 Train=0.0180  Test=0.2740  Acc=91.98%
# convnext_tiny Teacher | Epoch 20 Train=0.0100  Test=0.2979  Acc=92.39%
# convnext_tiny Teacher | Epoch 21 Train=0.0024  Test=0.2388  Acc=93.00%
# convnext_tiny Teacher | Epoch 22 Train=0.0015  Test=0.2452  Acc=93.62%
# convnext_tiny Teacher | Epoch 23 Train=0.0027  Test=0.2560  Acc=93.83%
# convnext_tiny Teacher | Epoch 24 Train=0.0009  Test=0.2681  Acc=93.42%
# convnext_tiny Teacher | Epoch 25 Train=0.0009  Test=0.2787  Acc=92.39%
# convnext_tiny Teacher | Epoch 26 Train=0.0009  Test=0.2857  Acc=92.59%
# convnext_tiny Teacher | Epoch 27 Train=0.0013  Test=0.2876  Acc=92.39%
# convnext_tiny Teacher | Epoch 28 Train=0.0009  Test=0.2840  Acc=92.59%
# convnext_tiny Teacher | Epoch 29 Train=0.0009  Test=0.2786  Acc=92.80%
# convnext_tiny Teacher | Epoch 30 Train=0.0008  Test=0.2737  Acc=93.21%
# convnext_tiny Teacher | Epoch 31 Train=0.0008  Test=0.2696  Acc=93.62%
# convnext_tiny Teacher | Epoch 32 Train=0.0005  Test=0.2675  Acc=93.62%
# convnext_tiny Teacher | Epoch 33 Train=0.0017  Test=0.2650  Acc=93.62%
# convnext_tiny Teacher | Epoch 34 Train=0.0004  Test=0.2803  Acc=93.83%
# convnext_tiny Teacher | Epoch 35 Train=0.0005  Test=0.3065  Acc=93.42%
# convnext_tiny Teacher | Epoch 36 Train=0.0010  Test=0.3100  Acc=93.62%
# convnext_tiny Teacher | Epoch 37 Train=0.0012  Test=0.2871  Acc=94.24%
# ✔ Saved TEACHER checkpoint (94.24%)
# convnext_tiny Teacher | Epoch 38 Train=0.0008  Test=0.2572  Acc=94.24%
# convnext_tiny Teacher | Epoch 39 Train=0.0003  Test=0.2473  Acc=94.44%
# ✔ Saved TEACHER checkpoint (94.44%)
# convnext_tiny Teacher | Epoch 40 Train=0.0003  Test=0.2477  Acc=93.83%
# convnext_tiny Teacher | Epoch 41 Train=0.0004  Test=0.2500  Acc=93.62%
# convnext_tiny Teacher | Epoch 42 Train=0.0003  Test=0.2533  Acc=93.62%
# convnext_tiny Teacher | Epoch 43 Train=0.0003  Test=0.2567  Acc=93.62%
# convnext_tiny Teacher | Epoch 44 Train=0.0007  Test=0.2605  Acc=93.83%
# convnext_tiny Teacher | Epoch 45 Train=0.0010  Test=0.2602  Acc=93.83%
# convnext_tiny Teacher | Epoch 46 Train=0.0003  Test=0.2593  Acc=93.83%
# convnext_tiny Teacher | Epoch 47 Train=0.0004  Test=0.2576  Acc=93.83%
# convnext_tiny Teacher | Epoch 48 Train=0.0003  Test=0.2560  Acc=93.42%
# convnext_tiny Teacher | Epoch 49 Train=0.0003  Test=0.2541  Acc=93.42%
# convnext_tiny Teacher | Epoch 50 Train=0.0003  Test=0.2525  Acc=93.83%
# convnext_tiny Teacher | Epoch 51 Train=0.0003  Test=0.2511  Acc=93.83%
# convnext_tiny Teacher | Epoch 52 Train=0.0003  Test=0.2501  Acc=93.83%
# convnext_tiny Teacher | Epoch 53 Train=0.0003  Test=0.2492  Acc=93.83%
# convnext_tiny Teacher | Epoch 54 Train=0.0003  Test=0.2485  Acc=93.83%
# convnext_tiny Teacher | Epoch 55 Train=0.0002  Test=0.2479  Acc=93.83%
# convnext_tiny Teacher | Epoch 56 Train=0.0002  Test=0.2475  Acc=94.03%
# convnext_tiny Teacher | Epoch 57 Train=0.0002  Test=0.2472  Acc=94.03%
# convnext_tiny Teacher | Epoch 58 Train=0.0002  Test=0.2470  Acc=94.03%
# convnext_tiny Teacher | Epoch 59 Train=0.0002  Test=0.2470  Acc=94.03%
# convnext_tiny Teacher | Epoch 60 Train=0.0003  Test=0.2471  Acc=94.03%
# convnext_tiny Teacher | Epoch 61 Train=0.0027  Test=0.2473  Acc=94.03%
# convnext_tiny Teacher | Epoch 62 Train=0.0002  Test=0.2479  Acc=94.03%
# convnext_tiny Teacher | Epoch 63 Train=0.0002  Test=0.2488  Acc=94.03%
# convnext_tiny Teacher | Epoch 64 Train=0.0004  Test=0.2491  Acc=94.03%
# convnext_tiny Teacher | Epoch 65 Train=0.0002  Test=0.2495  Acc=94.24%
# convnext_tiny Teacher | Epoch 66 Train=0.0002  Test=0.2499  Acc=94.24%
# convnext_tiny Teacher | Epoch 67 Train=0.0002  Test=0.2502  Acc=94.24%
# convnext_tiny Teacher | Epoch 68 Train=0.0002  Test=0.2505  Acc=94.24%
# convnext_tiny Teacher | Epoch 69 Train=0.0002  Test=0.2507  Acc=94.24%
# ⛔ Early stopping (teacher)
# 🏁 Finished TEACHER for convnext_tiny. Best Acc=94.44%
#
# ======================================================================
# 🔥 Training TEACHER model: resnet18
# ======================================================================
# /home/ifran/miniconda3/envs/pytorch/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# resnet18 Teacher | Epoch 0 Train=1.3590  Test=1.0582  Acc=70.58%
# ✔ Saved TEACHER checkpoint (70.58%)
# resnet18 Teacher | Epoch 1 Train=0.2121  Test=1.2023  Acc=72.02%
# ✔ Saved TEACHER checkpoint (72.02%)
# resnet18 Teacher | Epoch 2 Train=0.0732  Test=1.8390  Acc=72.84%
# ✔ Saved TEACHER checkpoint (72.84%)
# resnet18 Teacher | Epoch 3 Train=0.0297  Test=1.6225  Acc=77.16%
# ✔ Saved TEACHER checkpoint (77.16%)
# resnet18 Teacher | Epoch 4 Train=0.0414  Test=1.7686  Acc=74.49%
# resnet18 Teacher | Epoch 5 Train=0.0349  Test=1.3623  Acc=75.72%
# resnet18 Teacher | Epoch 6 Train=0.0160  Test=1.1133  Acc=81.07%
# ✔ Saved TEACHER checkpoint (81.07%)
# resnet18 Teacher | Epoch 7 Train=0.0204  Test=0.9064  Acc=84.57%
# ✔ Saved TEACHER checkpoint (84.57%)
# resnet18 Teacher | Epoch 8 Train=0.0576  Test=0.5136  Acc=90.33%
# ✔ Saved TEACHER checkpoint (90.33%)
# resnet18 Teacher | Epoch 9 Train=0.0407  Test=0.7782  Acc=88.07%
# resnet18 Teacher | Epoch 10 Train=0.0316  Test=2.0481  Acc=77.37%
# resnet18 Teacher | Epoch 11 Train=0.0288  Test=1.8380  Acc=78.81%
# resnet18 Teacher | Epoch 12 Train=0.0147  Test=1.0831  Acc=79.84%
# resnet18 Teacher | Epoch 13 Train=0.0215  Test=0.8874  Acc=82.30%
# resnet18 Teacher | Epoch 14 Train=0.0288  Test=0.7851  Acc=82.92%
# resnet18 Teacher | Epoch 15 Train=0.0108  Test=0.8817  Acc=84.36%
# resnet18 Teacher | Epoch 16 Train=0.0120  Test=0.8695  Acc=84.36%
# resnet18 Teacher | Epoch 17 Train=0.0236  Test=0.7616  Acc=84.57%
# resnet18 Teacher | Epoch 18 Train=0.0215  Test=0.7351  Acc=85.80%
# resnet18 Teacher | Epoch 19 Train=0.0195  Test=0.7447  Acc=85.80%
# resnet18 Teacher | Epoch 20 Train=0.0140  Test=0.6383  Acc=87.86%
# resnet18 Teacher | Epoch 21 Train=0.0063  Test=0.5300  Acc=88.07%
# resnet18 Teacher | Epoch 22 Train=0.0026  Test=0.4696  Acc=89.71%
# resnet18 Teacher | Epoch 23 Train=0.0022  Test=0.4298  Acc=90.12%
# resnet18 Teacher | Epoch 24 Train=0.0014  Test=0.4089  Acc=90.95%
# ✔ Saved TEACHER checkpoint (90.95%)
# resnet18 Teacher | Epoch 25 Train=0.0026  Test=0.3860  Acc=91.15%
# ✔ Saved TEACHER checkpoint (91.15%)
# resnet18 Teacher | Epoch 26 Train=0.0011  Test=0.3674  Acc=91.56%
# ✔ Saved TEACHER checkpoint (91.56%)
# resnet18 Teacher | Epoch 27 Train=0.0084  Test=0.3334  Acc=91.98%
# ✔ Saved TEACHER checkpoint (91.98%)
# resnet18 Teacher | Epoch 28 Train=0.0011  Test=0.3148  Acc=91.98%
# resnet18 Teacher | Epoch 29 Train=0.0012  Test=0.3049  Acc=92.80%
# ✔ Saved TEACHER checkpoint (92.80%)
# resnet18 Teacher | Epoch 30 Train=0.0004  Test=0.3000  Acc=93.00%
# ✔ Saved TEACHER checkpoint (93.00%)
# resnet18 Teacher | Epoch 31 Train=0.0004  Test=0.2997  Acc=93.21%
# ✔ Saved TEACHER checkpoint (93.21%)
# resnet18 Teacher | Epoch 32 Train=0.0004  Test=0.2998  Acc=93.21%
# resnet18 Teacher | Epoch 33 Train=0.0003  Test=0.3008  Acc=93.62%
# ✔ Saved TEACHER checkpoint (93.62%)
# resnet18 Teacher | Epoch 34 Train=0.0011  Test=0.3063  Acc=93.42%
# resnet18 Teacher | Epoch 35 Train=0.0004  Test=0.3109  Acc=93.21%
# resnet18 Teacher | Epoch 36 Train=0.0003  Test=0.3131  Acc=93.21%
# resnet18 Teacher | Epoch 37 Train=0.0003  Test=0.3152  Acc=93.00%
# resnet18 Teacher | Epoch 38 Train=0.0002  Test=0.3159  Acc=92.59%
# resnet18 Teacher | Epoch 39 Train=0.0004  Test=0.3162  Acc=92.80%
# resnet18 Teacher | Epoch 40 Train=0.0002  Test=0.3162  Acc=93.00%
# resnet18 Teacher | Epoch 41 Train=0.0002  Test=0.3160  Acc=93.00%
# resnet18 Teacher | Epoch 42 Train=0.0002  Test=0.3159  Acc=92.80%
# resnet18 Teacher | Epoch 43 Train=0.0003  Test=0.3149  Acc=93.00%
# resnet18 Teacher | Epoch 44 Train=0.0002  Test=0.3156  Acc=93.00%
# resnet18 Teacher | Epoch 45 Train=0.0002  Test=0.3161  Acc=92.59%
# resnet18 Teacher | Epoch 46 Train=0.0002  Test=0.3164  Acc=92.59%
# resnet18 Teacher | Epoch 47 Train=0.0004  Test=0.3166  Acc=92.80%
# resnet18 Teacher | Epoch 48 Train=0.0002  Test=0.3156  Acc=93.42%
# resnet18 Teacher | Epoch 49 Train=0.0002  Test=0.3149  Acc=93.21%
# resnet18 Teacher | Epoch 50 Train=0.0002  Test=0.3121  Acc=93.21%
# resnet18 Teacher | Epoch 51 Train=0.0003  Test=0.3086  Acc=93.21%
# resnet18 Teacher | Epoch 52 Train=0.0001  Test=0.3071  Acc=93.21%
# resnet18 Teacher | Epoch 53 Train=0.0004  Test=0.3051  Acc=93.21%
# resnet18 Teacher | Epoch 54 Train=0.0002  Test=0.3036  Acc=93.21%
# resnet18 Teacher | Epoch 55 Train=0.0002  Test=0.3017  Acc=93.62%
# resnet18 Teacher | Epoch 56 Train=0.0001  Test=0.3010  Acc=93.42%
# resnet18 Teacher | Epoch 57 Train=0.0002  Test=0.3003  Acc=93.42%
# resnet18 Teacher | Epoch 58 Train=0.0002  Test=0.3010  Acc=93.42%
# resnet18 Teacher | Epoch 59 Train=0.0001  Test=0.3010  Acc=93.42%
# resnet18 Teacher | Epoch 60 Train=0.0001  Test=0.3000  Acc=93.42%
# resnet18 Teacher | Epoch 61 Train=0.0002  Test=0.2991  Acc=93.42%
# resnet18 Teacher | Epoch 62 Train=0.0001  Test=0.2988  Acc=93.42%
# resnet18 Teacher | Epoch 63 Train=0.0002  Test=0.2995  Acc=93.42%
# ⛔ Early stopping (teacher)
# 🏁 Finished TEACHER for resnet18. Best Acc=93.62%
#
# ======================================================================
# 🔥 Training TEACHER model: efficientnet_b0
# ======================================================================
# /home/ifran/miniconda3/envs/pytorch/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# efficientnet_b0 Teacher | Epoch 0 Train=1.7604  Test=1.7490  Acc=39.71%
# ✔ Saved TEACHER checkpoint (39.71%)
# efficientnet_b0 Teacher | Epoch 1 Train=0.7718  Test=1.3383  Acc=49.79%
# ✔ Saved TEACHER checkpoint (49.79%)
# efficientnet_b0 Teacher | Epoch 2 Train=0.3033  Test=0.9530  Acc=70.78%
# ✔ Saved TEACHER checkpoint (70.78%)
# efficientnet_b0 Teacher | Epoch 3 Train=0.1257  Test=0.6427  Acc=83.54%
# ✔ Saved TEACHER checkpoint (83.54%)
# efficientnet_b0 Teacher | Epoch 4 Train=0.0630  Test=0.4963  Acc=88.48%
# ✔ Saved TEACHER checkpoint (88.48%)
# efficientnet_b0 Teacher | Epoch 5 Train=0.0353  Test=0.4038  Acc=90.53%
# ✔ Saved TEACHER checkpoint (90.53%)
# efficientnet_b0 Teacher | Epoch 6 Train=0.0187  Test=0.3625  Acc=91.77%
# ✔ Saved TEACHER checkpoint (91.77%)
# efficientnet_b0 Teacher | Epoch 7 Train=0.0075  Test=0.3448  Acc=92.80%
# ✔ Saved TEACHER checkpoint (92.80%)
# efficientnet_b0 Teacher | Epoch 8 Train=0.0075  Test=0.3342  Acc=92.80%
# efficientnet_b0 Teacher | Epoch 9 Train=0.0014  Test=0.3328  Acc=93.42%
# ✔ Saved TEACHER checkpoint (93.42%)
# efficientnet_b0 Teacher | Epoch 10 Train=0.0017  Test=0.3269  Acc=93.62%
# ✔ Saved TEACHER checkpoint (93.62%)
# efficientnet_b0 Teacher | Epoch 11 Train=0.0009  Test=0.3255  Acc=93.62%
# efficientnet_b0 Teacher | Epoch 12 Train=0.0011  Test=0.3131  Acc=94.65%
# ✔ Saved TEACHER checkpoint (94.65%)
# efficientnet_b0 Teacher | Epoch 13 Train=0.0003  Test=0.3048  Acc=94.65%
# efficientnet_b0 Teacher | Epoch 14 Train=0.0023  Test=0.2929  Acc=94.44%
# efficientnet_b0 Teacher | Epoch 15 Train=0.0015  Test=0.2744  Acc=95.06%
# ✔ Saved TEACHER checkpoint (95.06%)
# efficientnet_b0 Teacher | Epoch 16 Train=0.0023  Test=0.2621  Acc=95.68%
# ✔ Saved TEACHER checkpoint (95.68%)
# efficientnet_b0 Teacher | Epoch 17 Train=0.0016  Test=0.2570  Acc=95.88%
# ✔ Saved TEACHER checkpoint (95.88%)
# efficientnet_b0 Teacher | Epoch 18 Train=0.0002  Test=0.2626  Acc=95.88%
# efficientnet_b0 Teacher | Epoch 19 Train=0.0003  Test=0.2766  Acc=95.27%
# efficientnet_b0 Teacher | Epoch 20 Train=0.0003  Test=0.2824  Acc=94.65%
# efficientnet_b0 Teacher | Epoch 21 Train=0.0001  Test=0.2902  Acc=94.44%
# efficientnet_b0 Teacher | Epoch 22 Train=0.0001  Test=0.2975  Acc=94.24%
# efficientnet_b0 Teacher | Epoch 23 Train=0.0010  Test=0.3105  Acc=94.24%
# efficientnet_b0 Teacher | Epoch 24 Train=0.0006  Test=0.3197  Acc=94.24%
# efficientnet_b0 Teacher | Epoch 25 Train=0.0002  Test=0.3282  Acc=94.24%
# efficientnet_b0 Teacher | Epoch 26 Train=0.0004  Test=0.3322  Acc=93.83%
# efficientnet_b0 Teacher | Epoch 27 Train=0.0040  Test=0.3114  Acc=94.03%
# efficientnet_b0 Teacher | Epoch 28 Train=0.0001  Test=0.2936  Acc=94.24%
# efficientnet_b0 Teacher | Epoch 29 Train=0.0003  Test=0.2815  Acc=94.44%
# efficientnet_b0 Teacher | Epoch 30 Train=0.0003  Test=0.2749  Acc=94.65%
# efficientnet_b0 Teacher | Epoch 31 Train=0.0014  Test=0.2674  Acc=94.86%
# efficientnet_b0 Teacher | Epoch 32 Train=0.0002  Test=0.2634  Acc=95.06%
# efficientnet_b0 Teacher | Epoch 33 Train=0.0002  Test=0.2593  Acc=95.47%
# efficientnet_b0 Teacher | Epoch 34 Train=0.0005  Test=0.2591  Acc=95.06%
# efficientnet_b0 Teacher | Epoch 35 Train=0.0006  Test=0.2610  Acc=95.06%
# efficientnet_b0 Teacher | Epoch 36 Train=0.0010  Test=0.2614  Acc=95.06%
# efficientnet_b0 Teacher | Epoch 37 Train=0.0001  Test=0.2604  Acc=94.65%
# efficientnet_b0 Teacher | Epoch 38 Train=0.0008  Test=0.2617  Acc=94.44%
# efficientnet_b0 Teacher | Epoch 39 Train=0.0006  Test=0.2630  Acc=94.86%
# efficientnet_b0 Teacher | Epoch 40 Train=0.0001  Test=0.2620  Acc=94.65%
# efficientnet_b0 Teacher | Epoch 41 Train=0.0001  Test=0.2604  Acc=95.06%
# efficientnet_b0 Teacher | Epoch 42 Train=0.0047  Test=0.2483  Acc=95.47%
# efficientnet_b0 Teacher | Epoch 43 Train=0.0005  Test=0.2388  Acc=95.47%
# efficientnet_b0 Teacher | Epoch 44 Train=0.0001  Test=0.2278  Acc=95.47%
# efficientnet_b0 Teacher | Epoch 45 Train=0.0007  Test=0.2202  Acc=95.27%
# efficientnet_b0 Teacher | Epoch 46 Train=0.0001  Test=0.2177  Acc=95.68%
# efficientnet_b0 Teacher | Epoch 47 Train=0.0003  Test=0.2145  Acc=95.68%
# ⛔ Early stopping (teacher)
# 🏁 Finished TEACHER for efficientnet_b0. Best Acc=95.88%
#
# ======================================================================
# 🔥 Training TEACHER model: mobilenet_v2
# ======================================================================
# /home/ifran/miniconda3/envs/pytorch/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V2_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# mobilenet_v2 Teacher | Epoch 0 Train=1.4555  Test=3.1053  Acc=22.63%
# ✔ Saved TEACHER checkpoint (22.63%)
# mobilenet_v2 Teacher | Epoch 1 Train=0.2548  Test=3.5626  Acc=30.86%
# ✔ Saved TEACHER checkpoint (30.86%)
# mobilenet_v2 Teacher | Epoch 2 Train=0.0814  Test=3.1691  Acc=45.88%
# ✔ Saved TEACHER checkpoint (45.88%)
# mobilenet_v2 Teacher | Epoch 3 Train=0.0645  Test=1.9868  Acc=64.61%
# ✔ Saved TEACHER checkpoint (64.61%)
# mobilenet_v2 Teacher | Epoch 4 Train=0.0674  Test=1.2558  Acc=76.54%
# ✔ Saved TEACHER checkpoint (76.54%)
# mobilenet_v2 Teacher | Epoch 5 Train=0.0173  Test=1.3465  Acc=74.07%
# mobilenet_v2 Teacher | Epoch 6 Train=0.0533  Test=0.6803  Acc=87.24%
# ✔ Saved TEACHER checkpoint (87.24%)
# mobilenet_v2 Teacher | Epoch 7 Train=0.0111  Test=0.6086  Acc=85.80%
# mobilenet_v2 Teacher | Epoch 8 Train=0.0540  Test=0.5899  Acc=87.24%
# mobilenet_v2 Teacher | Epoch 9 Train=0.0063  Test=0.6666  Acc=87.65%
# ✔ Saved TEACHER checkpoint (87.65%)
# mobilenet_v2 Teacher | Epoch 10 Train=0.0073  Test=0.6653  Acc=86.83%
# mobilenet_v2 Teacher | Epoch 11 Train=0.0127  Test=0.5906  Acc=87.65%
# mobilenet_v2 Teacher | Epoch 12 Train=0.0033  Test=0.6508  Acc=86.83%
# mobilenet_v2 Teacher | Epoch 13 Train=0.0171  Test=0.5937  Acc=87.65%
# mobilenet_v2 Teacher | Epoch 14 Train=0.0048  Test=0.4172  Acc=89.71%
# ✔ Saved TEACHER checkpoint (89.71%)
# mobilenet_v2 Teacher | Epoch 15 Train=0.0022  Test=0.3455  Acc=90.33%
# ✔ Saved TEACHER checkpoint (90.33%)
# mobilenet_v2 Teacher | Epoch 16 Train=0.0022  Test=0.3306  Acc=92.39%
# ✔ Saved TEACHER checkpoint (92.39%)
# mobilenet_v2 Teacher | Epoch 17 Train=0.0026  Test=0.3362  Acc=92.80%
# ✔ Saved TEACHER checkpoint (92.80%)
# mobilenet_v2 Teacher | Epoch 18 Train=0.0029  Test=0.3244  Acc=93.00%
# ✔ Saved TEACHER checkpoint (93.00%)
# mobilenet_v2 Teacher | Epoch 19 Train=0.0080  Test=0.3231  Acc=92.18%
# mobilenet_v2 Teacher | Epoch 20 Train=0.0012  Test=0.3280  Acc=92.80%
# mobilenet_v2 Teacher | Epoch 21 Train=0.0018  Test=0.3270  Acc=93.00%
# mobilenet_v2 Teacher | Epoch 22 Train=0.0011  Test=0.3224  Acc=92.59%
# mobilenet_v2 Teacher | Epoch 23 Train=0.0011  Test=0.3163  Acc=92.80%
# mobilenet_v2 Teacher | Epoch 24 Train=0.0008  Test=0.3065  Acc=92.59%
# mobilenet_v2 Teacher | Epoch 25 Train=0.0006  Test=0.2959  Acc=92.59%
# mobilenet_v2 Teacher | Epoch 26 Train=0.0005  Test=0.2916  Acc=93.21%
# ✔ Saved TEACHER checkpoint (93.21%)
# mobilenet_v2 Teacher | Epoch 27 Train=0.0008  Test=0.2858  Acc=93.00%
# mobilenet_v2 Teacher | Epoch 28 Train=0.0005  Test=0.2799  Acc=93.21%
# mobilenet_v2 Teacher | Epoch 29 Train=0.0004  Test=0.2754  Acc=93.00%
# mobilenet_v2 Teacher | Epoch 30 Train=0.0007  Test=0.2716  Acc=93.00%
# mobilenet_v2 Teacher | Epoch 31 Train=0.0003  Test=0.2728  Acc=93.00%
# mobilenet_v2 Teacher | Epoch 32 Train=0.0002  Test=0.2742  Acc=93.00%
# mobilenet_v2 Teacher | Epoch 33 Train=0.0001  Test=0.2734  Acc=93.21%
# mobilenet_v2 Teacher | Epoch 34 Train=0.0002  Test=0.2773  Acc=93.00%
# mobilenet_v2 Teacher | Epoch 35 Train=0.0003  Test=0.2759  Acc=92.80%
# mobilenet_v2 Teacher | Epoch 36 Train=0.0002  Test=0.2764  Acc=93.00%
# mobilenet_v2 Teacher | Epoch 37 Train=0.0003  Test=0.2755  Acc=93.00%
# mobilenet_v2 Teacher | Epoch 38 Train=0.0001  Test=0.2787  Acc=93.00%
# mobilenet_v2 Teacher | Epoch 39 Train=0.0001  Test=0.2782  Acc=93.42%
# ✔ Saved TEACHER checkpoint (93.42%)
# mobilenet_v2 Teacher | Epoch 40 Train=0.0001  Test=0.2779  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 41 Train=0.0002  Test=0.2758  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 42 Train=0.0001  Test=0.2753  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 43 Train=0.0001  Test=0.2744  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 44 Train=0.0002  Test=0.2746  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 45 Train=0.0001  Test=0.2763  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 46 Train=0.0001  Test=0.2747  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 47 Train=0.0001  Test=0.2753  Acc=93.21%
# mobilenet_v2 Teacher | Epoch 48 Train=0.0001  Test=0.2752  Acc=93.21%
# mobilenet_v2 Teacher | Epoch 49 Train=0.0001  Test=0.2763  Acc=93.21%
# mobilenet_v2 Teacher | Epoch 50 Train=0.0003  Test=0.2760  Acc=93.21%
# mobilenet_v2 Teacher | Epoch 51 Train=0.0002  Test=0.2763  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 52 Train=0.0001  Test=0.2742  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 53 Train=0.0001  Test=0.2735  Acc=93.21%
# mobilenet_v2 Teacher | Epoch 54 Train=0.0002  Test=0.2732  Acc=93.21%
# mobilenet_v2 Teacher | Epoch 55 Train=0.0001  Test=0.2731  Acc=93.21%
# mobilenet_v2 Teacher | Epoch 56 Train=0.0001  Test=0.2727  Acc=93.21%
# mobilenet_v2 Teacher | Epoch 57 Train=0.0001  Test=0.2744  Acc=93.21%
# mobilenet_v2 Teacher | Epoch 58 Train=0.0001  Test=0.2747  Acc=93.21%
# mobilenet_v2 Teacher | Epoch 59 Train=0.0001  Test=0.2735  Acc=93.21%
# mobilenet_v2 Teacher | Epoch 60 Train=0.0004  Test=0.2760  Acc=93.62%
# ✔ Saved TEACHER checkpoint (93.62%)
# mobilenet_v2 Teacher | Epoch 61 Train=0.0001  Test=0.2774  Acc=93.21%
# mobilenet_v2 Teacher | Epoch 62 Train=0.0001  Test=0.2800  Acc=93.21%
# mobilenet_v2 Teacher | Epoch 63 Train=0.0001  Test=0.2819  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 64 Train=0.0002  Test=0.2852  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 65 Train=0.0001  Test=0.2858  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 66 Train=0.0001  Test=0.2848  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 67 Train=0.0001  Test=0.2854  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 68 Train=0.0001  Test=0.2870  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 69 Train=0.0001  Test=0.2869  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 70 Train=0.0001  Test=0.2870  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 71 Train=0.0001  Test=0.2863  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 72 Train=0.0003  Test=0.2883  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 73 Train=0.0001  Test=0.2865  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 74 Train=0.0001  Test=0.2830  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 75 Train=0.0001  Test=0.2812  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 76 Train=0.0001  Test=0.2808  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 77 Train=0.0001  Test=0.2809  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 78 Train=0.0001  Test=0.2810  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 79 Train=0.0001  Test=0.2802  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 80 Train=0.0001  Test=0.2802  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 81 Train=0.0001  Test=0.2803  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 82 Train=0.0001  Test=0.2802  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 83 Train=0.0001  Test=0.2797  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 84 Train=0.0002  Test=0.2815  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 85 Train=0.0001  Test=0.2798  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 86 Train=0.0001  Test=0.2788  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 87 Train=0.0001  Test=0.2770  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 88 Train=0.0001  Test=0.2766  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 89 Train=0.0001  Test=0.2763  Acc=93.42%
# mobilenet_v2 Teacher | Epoch 90 Train=0.0001  Test=0.2742  Acc=93.42%
# ⛔ Early stopping (teacher)
# 🏁 Finished TEACHER for mobilenet_v2. Best Acc=93.62%
#
# ======================================================================
# 🔥 Training TEACHER model: mobilenetv3_small
# ======================================================================
# /home/ifran/miniconda3/envs/pytorch/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V3_Small_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V3_Small_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# mobilenetv3_small Teacher | Epoch 0 Train=1.7575  Test=1.6931  Acc=49.38%
# ✔ Saved TEACHER checkpoint (49.38%)
# mobilenetv3_small Teacher | Epoch 1 Train=0.7740  Test=1.3488  Acc=61.73%
# ✔ Saved TEACHER checkpoint (61.73%)
# mobilenetv3_small Teacher | Epoch 2 Train=0.3557  Test=1.0918  Acc=62.35%
# ✔ Saved TEACHER checkpoint (62.35%)
# mobilenetv3_small Teacher | Epoch 3 Train=0.1591  Test=1.0418  Acc=61.11%
# mobilenetv3_small Teacher | Epoch 4 Train=0.0839  Test=1.1039  Acc=62.35%
# mobilenetv3_small Teacher | Epoch 5 Train=0.0424  Test=1.2435  Acc=61.73%
# mobilenetv3_small Teacher | Epoch 6 Train=0.0173  Test=1.3978  Acc=61.32%
# mobilenetv3_small Teacher | Epoch 7 Train=0.0107  Test=1.5200  Acc=61.32%
# mobilenetv3_small Teacher | Epoch 8 Train=0.0033  Test=1.5890  Acc=61.93%
# mobilenetv3_small Teacher | Epoch 9 Train=0.0029  Test=1.6417  Acc=62.76%
# ✔ Saved TEACHER checkpoint (62.76%)
# mobilenetv3_small Teacher | Epoch 10 Train=0.0010  Test=1.6882  Acc=63.99%
# ✔ Saved TEACHER checkpoint (63.99%)
# mobilenetv3_small Teacher | Epoch 11 Train=0.0013  Test=1.7382  Acc=65.02%
# ✔ Saved TEACHER checkpoint (65.02%)
# mobilenetv3_small Teacher | Epoch 12 Train=0.0008  Test=1.7740  Acc=65.64%
# ✔ Saved TEACHER checkpoint (65.64%)
# mobilenetv3_small Teacher | Epoch 13 Train=0.0002  Test=1.7943  Acc=66.05%
# ✔ Saved TEACHER checkpoint (66.05%)
# mobilenetv3_small Teacher | Epoch 14 Train=0.0003  Test=1.7989  Acc=66.87%
# ✔ Saved TEACHER checkpoint (66.87%)
# mobilenetv3_small Teacher | Epoch 15 Train=0.0002  Test=1.8020  Acc=67.49%
# ✔ Saved TEACHER checkpoint (67.49%)
# mobilenetv3_small Teacher | Epoch 16 Train=0.0003  Test=1.7869  Acc=68.31%
# ✔ Saved TEACHER checkpoint (68.31%)
# mobilenetv3_small Teacher | Epoch 17 Train=0.0002  Test=1.7669  Acc=68.72%
# ✔ Saved TEACHER checkpoint (68.72%)
# mobilenetv3_small Teacher | Epoch 18 Train=0.0002  Test=1.7289  Acc=69.14%
# ✔ Saved TEACHER checkpoint (69.14%)
# mobilenetv3_small Teacher | Epoch 19 Train=0.0001  Test=1.6948  Acc=70.37%
# ✔ Saved TEACHER checkpoint (70.37%)
# mobilenetv3_small Teacher | Epoch 20 Train=0.0001  Test=1.6532  Acc=71.81%
# ✔ Saved TEACHER checkpoint (71.81%)
# mobilenetv3_small Teacher | Epoch 21 Train=0.0002  Test=1.6127  Acc=72.43%
# ✔ Saved TEACHER checkpoint (72.43%)
# mobilenetv3_small Teacher | Epoch 22 Train=0.0001  Test=1.5725  Acc=73.87%
# ✔ Saved TEACHER checkpoint (73.87%)
# mobilenetv3_small Teacher | Epoch 23 Train=0.0001  Test=1.5352  Acc=75.72%
# ✔ Saved TEACHER checkpoint (75.72%)
# mobilenetv3_small Teacher | Epoch 24 Train=0.0002  Test=1.4987  Acc=76.34%
# ✔ Saved TEACHER checkpoint (76.34%)
# mobilenetv3_small Teacher | Epoch 25 Train=0.0003  Test=1.4679  Acc=76.75%
# ✔ Saved TEACHER checkpoint (76.75%)
# mobilenetv3_small Teacher | Epoch 26 Train=0.0001  Test=1.4395  Acc=77.37%
# ✔ Saved TEACHER checkpoint (77.37%)
# mobilenetv3_small Teacher | Epoch 27 Train=0.0007  Test=1.4013  Acc=78.19%
# ✔ Saved TEACHER checkpoint (78.19%)
# mobilenetv3_small Teacher | Epoch 28 Train=0.0000  Test=1.3637  Acc=79.22%
# ✔ Saved TEACHER checkpoint (79.22%)
# mobilenetv3_small Teacher | Epoch 29 Train=0.0000  Test=1.3303  Acc=79.84%
# ✔ Saved TEACHER checkpoint (79.84%)
# mobilenetv3_small Teacher | Epoch 30 Train=0.0000  Test=1.2998  Acc=80.66%
# ✔ Saved TEACHER checkpoint (80.66%)
# mobilenetv3_small Teacher | Epoch 31 Train=0.0000  Test=1.2700  Acc=81.07%
# ✔ Saved TEACHER checkpoint (81.07%)
# mobilenetv3_small Teacher | Epoch 32 Train=0.0000  Test=1.2412  Acc=81.28%
# ✔ Saved TEACHER checkpoint (81.28%)
# mobilenetv3_small Teacher | Epoch 33 Train=0.0000  Test=1.2129  Acc=81.48%
# ✔ Saved TEACHER checkpoint (81.48%)
# mobilenetv3_small Teacher | Epoch 34 Train=0.0000  Test=1.1879  Acc=82.30%
# ✔ Saved TEACHER checkpoint (82.30%)
# mobilenetv3_small Teacher | Epoch 35 Train=0.0000  Test=1.1633  Acc=82.30%
# mobilenetv3_small Teacher | Epoch 36 Train=0.0000  Test=1.1390  Acc=82.92%
# ✔ Saved TEACHER checkpoint (82.92%)
# mobilenetv3_small Teacher | Epoch 37 Train=0.0000  Test=1.1153  Acc=82.92%
# mobilenetv3_small Teacher | Epoch 38 Train=0.0000  Test=1.0932  Acc=82.92%
# mobilenetv3_small Teacher | Epoch 39 Train=0.0001  Test=1.0722  Acc=82.92%
# mobilenetv3_small Teacher | Epoch 40 Train=0.0000  Test=1.0518  Acc=82.92%
# mobilenetv3_small Teacher | Epoch 41 Train=0.0001  Test=1.0326  Acc=83.13%
# ✔ Saved TEACHER checkpoint (83.13%)
# mobilenetv3_small Teacher | Epoch 42 Train=0.0002  Test=1.0157  Acc=83.95%
# ✔ Saved TEACHER checkpoint (83.95%)
# mobilenetv3_small Teacher | Epoch 43 Train=0.0000  Test=0.9996  Acc=84.36%
# ✔ Saved TEACHER checkpoint (84.36%)
# mobilenetv3_small Teacher | Epoch 44 Train=0.0000  Test=0.9851  Acc=84.16%
# mobilenetv3_small Teacher | Epoch 45 Train=0.0000  Test=0.9718  Acc=84.57%
# ✔ Saved TEACHER checkpoint (84.57%)
# mobilenetv3_small Teacher | Epoch 46 Train=0.0000  Test=0.9613  Acc=84.98%
# ✔ Saved TEACHER checkpoint (84.98%)
# mobilenetv3_small Teacher | Epoch 47 Train=0.0000  Test=0.9522  Acc=85.39%
# ✔ Saved TEACHER checkpoint (85.39%)
# mobilenetv3_small Teacher | Epoch 48 Train=0.0002  Test=0.9438  Acc=85.19%
# mobilenetv3_small Teacher | Epoch 49 Train=0.0000  Test=0.9377  Acc=84.98%
# mobilenetv3_small Teacher | Epoch 50 Train=0.0000  Test=0.9315  Acc=85.19%
# mobilenetv3_small Teacher | Epoch 51 Train=0.0000  Test=0.9263  Acc=85.60%
# ✔ Saved TEACHER checkpoint (85.60%)
# mobilenetv3_small Teacher | Epoch 52 Train=0.0000  Test=0.9216  Acc=85.60%
# mobilenetv3_small Teacher | Epoch 53 Train=0.0000  Test=0.9170  Acc=85.60%
# mobilenetv3_small Teacher | Epoch 54 Train=0.0000  Test=0.9123  Acc=85.60%
# mobilenetv3_small Teacher | Epoch 55 Train=0.0001  Test=0.9064  Acc=85.60%
# mobilenetv3_small Teacher | Epoch 56 Train=0.0001  Test=0.9029  Acc=85.60%
# mobilenetv3_small Teacher | Epoch 57 Train=0.0000  Test=0.8978  Acc=85.80%
# ✔ Saved TEACHER checkpoint (85.80%)
# mobilenetv3_small Teacher | Epoch 58 Train=0.0000  Test=0.8933  Acc=85.60%
# mobilenetv3_small Teacher | Epoch 59 Train=0.0000  Test=0.8878  Acc=85.60%
# mobilenetv3_small Teacher | Epoch 60 Train=0.0001  Test=0.8815  Acc=85.80%
# mobilenetv3_small Teacher | Epoch 61 Train=0.0000  Test=0.8744  Acc=85.80%
# mobilenetv3_small Teacher | Epoch 62 Train=0.0000  Test=0.8667  Acc=86.01%
# ✔ Saved TEACHER checkpoint (86.01%)
# mobilenetv3_small Teacher | Epoch 63 Train=0.0001  Test=0.8589  Acc=85.80%
# mobilenetv3_small Teacher | Epoch 64 Train=0.0000  Test=0.8506  Acc=86.01%
# mobilenetv3_small Teacher | Epoch 65 Train=0.0001  Test=0.8426  Acc=86.01%
# mobilenetv3_small Teacher | Epoch 66 Train=0.0000  Test=0.8343  Acc=86.21%
# ✔ Saved TEACHER checkpoint (86.21%)
# mobilenetv3_small Teacher | Epoch 67 Train=0.0000  Test=0.8261  Acc=86.21%
# mobilenetv3_small Teacher | Epoch 68 Train=0.0000  Test=0.8182  Acc=86.01%
# mobilenetv3_small Teacher | Epoch 69 Train=0.0000  Test=0.8115  Acc=86.21%
# mobilenetv3_small Teacher | Epoch 70 Train=0.0001  Test=0.8050  Acc=86.21%
# mobilenetv3_small Teacher | Epoch 71 Train=0.0001  Test=0.7992  Acc=86.21%
# mobilenetv3_small Teacher | Epoch 72 Train=0.0000  Test=0.7936  Acc=86.21%
# mobilenetv3_small Teacher | Epoch 73 Train=0.0002  Test=0.7898  Acc=86.63%
# ✔ Saved TEACHER checkpoint (86.63%)
# mobilenetv3_small Teacher | Epoch 74 Train=0.0000  Test=0.7867  Acc=86.63%
# mobilenetv3_small Teacher | Epoch 75 Train=0.0000  Test=0.7831  Acc=86.63%
# mobilenetv3_small Teacher | Epoch 76 Train=0.0000  Test=0.7805  Acc=86.63%
# mobilenetv3_small Teacher | Epoch 77 Train=0.0000  Test=0.7774  Acc=86.83%
# ✔ Saved TEACHER checkpoint (86.83%)
# mobilenetv3_small Teacher | Epoch 78 Train=0.0000  Test=0.7735  Acc=86.83%
# mobilenetv3_small Teacher | Epoch 79 Train=0.0000  Test=0.7697  Acc=86.83%
# mobilenetv3_small Teacher | Epoch 80 Train=0.0000  Test=0.7659  Acc=87.04%
# ✔ Saved TEACHER checkpoint (87.04%)
# mobilenetv3_small Teacher | Epoch 81 Train=0.0000  Test=0.7621  Acc=87.04%
# mobilenetv3_small Teacher | Epoch 82 Train=0.0000  Test=0.7582  Acc=87.24%
# ✔ Saved TEACHER checkpoint (87.24%)
# mobilenetv3_small Teacher | Epoch 83 Train=0.0000  Test=0.7544  Acc=87.24%
# mobilenetv3_small Teacher | Epoch 84 Train=0.0000  Test=0.7506  Acc=87.24%
# mobilenetv3_small Teacher | Epoch 85 Train=0.0000  Test=0.7473  Acc=87.24%
# mobilenetv3_small Teacher | Epoch 86 Train=0.0000  Test=0.7438  Acc=87.24%
# mobilenetv3_small Teacher | Epoch 87 Train=0.0000  Test=0.7408  Acc=87.45%
# ✔ Saved TEACHER checkpoint (87.45%)
# mobilenetv3_small Teacher | Epoch 88 Train=0.0000  Test=0.7373  Acc=87.45%
# mobilenetv3_small Teacher | Epoch 89 Train=0.0001  Test=0.7339  Acc=87.65%
# ✔ Saved TEACHER checkpoint (87.65%)
# mobilenetv3_small Teacher | Epoch 90 Train=0.0000  Test=0.7310  Acc=87.86%
# ✔ Saved TEACHER checkpoint (87.86%)
# mobilenetv3_small Teacher | Epoch 91 Train=0.0000  Test=0.7278  Acc=87.86%
# mobilenetv3_small Teacher | Epoch 92 Train=0.0000  Test=0.7250  Acc=87.86%
# mobilenetv3_small Teacher | Epoch 93 Train=0.0001  Test=0.7222  Acc=88.07%
# ✔ Saved TEACHER checkpoint (88.07%)
# mobilenetv3_small Teacher | Epoch 94 Train=0.0000  Test=0.7196  Acc=87.86%
# mobilenetv3_small Teacher | Epoch 95 Train=0.0000  Test=0.7162  Acc=87.86%
# mobilenetv3_small Teacher | Epoch 96 Train=0.0000  Test=0.7127  Acc=87.86%
# mobilenetv3_small Teacher | Epoch 97 Train=0.0000  Test=0.7102  Acc=87.65%
# mobilenetv3_small Teacher | Epoch 98 Train=0.0000  Test=0.7073  Acc=87.65%
# mobilenetv3_small Teacher | Epoch 99 Train=0.0000  Test=0.7049  Acc=87.65%
# 🏁 Finished TEACHER for mobilenetv3_small. Best Acc=88.07%
#
# ======================================================================
# 🔥 Training TEACHER model: tinycnn
# ======================================================================
# tinycnn Teacher | Epoch 0 Train=1.8172  Test=1.9376  Acc=24.69%
# ✔ Saved TEACHER checkpoint (24.69%)
# tinycnn Teacher | Epoch 1 Train=1.4847  Test=1.9394  Acc=8.23%
# tinycnn Teacher | Epoch 2 Train=1.2491  Test=1.9485  Acc=13.17%
# tinycnn Teacher | Epoch 3 Train=1.1010  Test=1.9765  Acc=13.17%
# tinycnn Teacher | Epoch 4 Train=0.9751  Test=2.0327  Acc=13.17%
# tinycnn Teacher | Epoch 5 Train=0.8982  Test=2.1277  Acc=13.17%
# tinycnn Teacher | Epoch 6 Train=0.8314  Test=2.2635  Acc=15.84%
# tinycnn Teacher | Epoch 7 Train=0.7673  Test=2.4271  Acc=12.96%
# tinycnn Teacher | Epoch 8 Train=0.7245  Test=2.6159  Acc=12.35%
# tinycnn Teacher | Epoch 9 Train=0.6780  Test=2.8141  Acc=13.37%
# tinycnn Teacher | Epoch 10 Train=0.6232  Test=3.0022  Acc=14.81%
# tinycnn Teacher | Epoch 11 Train=0.5965  Test=3.1755  Acc=16.87%
# tinycnn Teacher | Epoch 12 Train=0.5604  Test=3.3178  Acc=18.11%
# tinycnn Teacher | Epoch 13 Train=0.5307  Test=3.4312  Acc=18.93%
# tinycnn Teacher | Epoch 14 Train=0.4933  Test=3.4850  Acc=19.14%
# tinycnn Teacher | Epoch 15 Train=0.4583  Test=3.3915  Acc=19.75%
# tinycnn Teacher | Epoch 16 Train=0.4126  Test=3.1305  Acc=20.58%
# tinycnn Teacher | Epoch 17 Train=0.3885  Test=2.7505  Acc=24.69%
# tinycnn Teacher | Epoch 18 Train=0.3659  Test=2.2924  Acc=30.45%
# ✔ Saved TEACHER checkpoint (30.45%)
# tinycnn Teacher | Epoch 19 Train=0.3486  Test=1.8353  Acc=38.48%
# ✔ Saved TEACHER checkpoint (38.48%)
# tinycnn Teacher | Epoch 20 Train=0.3305  Test=1.4504  Acc=46.30%
# ✔ Saved TEACHER checkpoint (46.30%)
# tinycnn Teacher | Epoch 21 Train=0.2971  Test=1.1557  Acc=55.97%
# ✔ Saved TEACHER checkpoint (55.97%)
# tinycnn Teacher | Epoch 22 Train=0.2899  Test=0.9401  Acc=64.61%
# ✔ Saved TEACHER checkpoint (64.61%)
# tinycnn Teacher | Epoch 23 Train=0.2648  Test=0.7826  Acc=70.78%
# ✔ Saved TEACHER checkpoint (70.78%)
# tinycnn Teacher | Epoch 24 Train=0.2710  Test=0.6622  Acc=75.93%
# ✔ Saved TEACHER checkpoint (75.93%)
# tinycnn Teacher | Epoch 25 Train=0.2618  Test=0.5854  Acc=80.04%
# ✔ Saved TEACHER checkpoint (80.04%)
# tinycnn Teacher | Epoch 26 Train=0.2369  Test=0.5397  Acc=80.04%
# tinycnn Teacher | Epoch 27 Train=0.2223  Test=0.5164  Acc=81.48%
# ✔ Saved TEACHER checkpoint (81.48%)
# tinycnn Teacher | Epoch 28 Train=0.2309  Test=0.5083  Acc=82.51%
# ✔ Saved TEACHER checkpoint (82.51%)
# tinycnn Teacher | Epoch 29 Train=0.2034  Test=0.4984  Acc=81.89%
# tinycnn Teacher | Epoch 30 Train=0.2092  Test=0.4877  Acc=81.28%
# tinycnn Teacher | Epoch 31 Train=0.1882  Test=0.4763  Acc=81.69%
# tinycnn Teacher | Epoch 32 Train=0.1813  Test=0.4684  Acc=82.51%
# tinycnn Teacher | Epoch 33 Train=0.1704  Test=0.4669  Acc=81.89%
# tinycnn Teacher | Epoch 34 Train=0.1723  Test=0.4741  Acc=81.69%
# tinycnn Teacher | Epoch 35 Train=0.1594  Test=0.4738  Acc=81.28%
# tinycnn Teacher | Epoch 36 Train=0.1442  Test=0.4691  Acc=82.30%
# tinycnn Teacher | Epoch 37 Train=0.1359  Test=0.4667  Acc=82.10%
# tinycnn Teacher | Epoch 38 Train=0.1443  Test=0.4636  Acc=82.51%
# tinycnn Teacher | Epoch 39 Train=0.1276  Test=0.4630  Acc=83.13%
# ✔ Saved TEACHER checkpoint (83.13%)
# tinycnn Teacher | Epoch 40 Train=0.1292  Test=0.4623  Acc=83.13%
# tinycnn Teacher | Epoch 41 Train=0.1122  Test=0.4604  Acc=83.13%
# tinycnn Teacher | Epoch 42 Train=0.1192  Test=0.4550  Acc=82.51%
# tinycnn Teacher | Epoch 43 Train=0.1046  Test=0.4523  Acc=82.92%
# tinycnn Teacher | Epoch 44 Train=0.1151  Test=0.4513  Acc=82.72%
# tinycnn Teacher | Epoch 45 Train=0.1149  Test=0.4476  Acc=83.33%
# ✔ Saved TEACHER checkpoint (83.33%)
# tinycnn Teacher | Epoch 46 Train=0.1060  Test=0.4481  Acc=83.13%
# tinycnn Teacher | Epoch 47 Train=0.1011  Test=0.4497  Acc=82.51%
# tinycnn Teacher | Epoch 48 Train=0.1011  Test=0.4512  Acc=82.10%
# tinycnn Teacher | Epoch 49 Train=0.0977  Test=0.4519  Acc=82.72%
# tinycnn Teacher | Epoch 50 Train=0.1026  Test=0.4516  Acc=82.92%
# tinycnn Teacher | Epoch 51 Train=0.0967  Test=0.4500  Acc=83.13%
# tinycnn Teacher | Epoch 52 Train=0.0930  Test=0.4490  Acc=83.13%
# tinycnn Teacher | Epoch 53 Train=0.0840  Test=0.4470  Acc=83.33%
# tinycnn Teacher | Epoch 54 Train=0.0857  Test=0.4457  Acc=83.33%
# tinycnn Teacher | Epoch 55 Train=0.0825  Test=0.4444  Acc=83.33%
# tinycnn Teacher | Epoch 56 Train=0.0858  Test=0.4463  Acc=83.54%
# ✔ Saved TEACHER checkpoint (83.54%)
# tinycnn Teacher | Epoch 57 Train=0.0808  Test=0.4463  Acc=83.33%
# tinycnn Teacher | Epoch 58 Train=0.0795  Test=0.4448  Acc=83.13%
# tinycnn Teacher | Epoch 59 Train=0.0723  Test=0.4429  Acc=83.13%
# tinycnn Teacher | Epoch 60 Train=0.0781  Test=0.4417  Acc=83.54%
# tinycnn Teacher | Epoch 61 Train=0.0732  Test=0.4410  Acc=83.74%
# ✔ Saved TEACHER checkpoint (83.74%)
# tinycnn Teacher | Epoch 62 Train=0.0660  Test=0.4401  Acc=83.74%
# tinycnn Teacher | Epoch 63 Train=0.0735  Test=0.4409  Acc=83.54%
# tinycnn Teacher | Epoch 64 Train=0.0749  Test=0.4417  Acc=83.54%
# tinycnn Teacher | Epoch 65 Train=0.0677  Test=0.4425  Acc=83.33%
# tinycnn Teacher | Epoch 66 Train=0.0654  Test=0.4418  Acc=83.33%
# tinycnn Teacher | Epoch 67 Train=0.0698  Test=0.4430  Acc=82.92%
# tinycnn Teacher | Epoch 68 Train=0.0670  Test=0.4443  Acc=83.13%
# tinycnn Teacher | Epoch 69 Train=0.0588  Test=0.4455  Acc=83.13%
# tinycnn Teacher | Epoch 70 Train=0.0679  Test=0.4460  Acc=83.33%
# tinycnn Teacher | Epoch 71 Train=0.0641  Test=0.4456  Acc=83.54%
# tinycnn Teacher | Epoch 72 Train=0.0632  Test=0.4444  Acc=83.54%
# tinycnn Teacher | Epoch 73 Train=0.0614  Test=0.4435  Acc=83.74%
# tinycnn Teacher | Epoch 74 Train=0.0574  Test=0.4433  Acc=83.54%
# tinycnn Teacher | Epoch 75 Train=0.0563  Test=0.4427  Acc=83.54%
# tinycnn Teacher | Epoch 76 Train=0.0594  Test=0.4417  Acc=83.33%
# tinycnn Teacher | Epoch 77 Train=0.0572  Test=0.4413  Acc=83.54%
# tinycnn Teacher | Epoch 78 Train=0.0752  Test=0.4424  Acc=83.33%
# tinycnn Teacher | Epoch 79 Train=0.0590  Test=0.4414  Acc=83.54%
# tinycnn Teacher | Epoch 80 Train=0.0552  Test=0.4408  Acc=83.74%
# tinycnn Teacher | Epoch 81 Train=0.0573  Test=0.4391  Acc=83.54%
# tinycnn Teacher | Epoch 82 Train=0.0568  Test=0.4388  Acc=83.74%
# tinycnn Teacher | Epoch 83 Train=0.0578  Test=0.4384  Acc=83.74%
# tinycnn Teacher | Epoch 84 Train=0.0526  Test=0.4379  Acc=83.74%
# tinycnn Teacher | Epoch 85 Train=0.0601  Test=0.4381  Acc=83.74%
# tinycnn Teacher | Epoch 86 Train=0.0665  Test=0.4394  Acc=83.74%
# tinycnn Teacher | Epoch 87 Train=0.0537  Test=0.4394  Acc=83.95%
# ✔ Saved TEACHER checkpoint (83.95%)
# tinycnn Teacher | Epoch 88 Train=0.0563  Test=0.4396  Acc=83.74%
# tinycnn Teacher | Epoch 89 Train=0.0574  Test=0.4395  Acc=83.95%
# tinycnn Teacher | Epoch 90 Train=0.0543  Test=0.4396  Acc=83.74%
# tinycnn Teacher | Epoch 91 Train=0.0510  Test=0.4403  Acc=83.74%
# tinycnn Teacher | Epoch 92 Train=0.0534  Test=0.4408  Acc=83.74%
# tinycnn Teacher | Epoch 93 Train=0.0508  Test=0.4412  Acc=83.95%
# tinycnn Teacher | Epoch 94 Train=0.0496  Test=0.4418  Acc=83.74%
# tinycnn Teacher | Epoch 95 Train=0.0500  Test=0.4418  Acc=83.74%
# tinycnn Teacher | Epoch 96 Train=0.0526  Test=0.4423  Acc=83.74%
# tinycnn Teacher | Epoch 97 Train=0.0475  Test=0.4433  Acc=83.74%
# tinycnn Teacher | Epoch 98 Train=0.0490  Test=0.4435  Acc=83.54%
# tinycnn Teacher | Epoch 99 Train=0.0504  Test=0.4431  Acc=83.74%
# 🏁 Finished TEACHER for tinycnn. Best Acc=83.95%
#
# ======================================================================
# 🎓 Training STUDENT model with KD: convnext_tiny
# ======================================================================
# /tmp/ipykernel_38837/608260745.py:148: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   teacher.load_state_dict(torch.load(f"Checkpoints/best_{name}.pth"))
# convnext_tiny Student | Epoch 0: TrainLoss=8.4438  Acc=48.56%
# ✔ Saved STUDENT checkpoint (48.56%)
# convnext_tiny Student | Epoch 1: TrainLoss=7.6470  Acc=70.78%
# ✔ Saved STUDENT checkpoint (70.78%)
# convnext_tiny Student | Epoch 2: TrainLoss=6.3423  Acc=44.03%
# convnext_tiny Student | Epoch 3: TrainLoss=8.1730  Acc=69.55%
# convnext_tiny Student | Epoch 4: TrainLoss=4.3537  Acc=79.01%
# ✔ Saved STUDENT checkpoint (79.01%)
# convnext_tiny Student | Epoch 5: TrainLoss=3.3909  Acc=81.28%
# ✔ Saved STUDENT checkpoint (81.28%)
# convnext_tiny Student | Epoch 6: TrainLoss=2.5318  Acc=87.24%
# ✔ Saved STUDENT checkpoint (87.24%)
# convnext_tiny Student | Epoch 7: TrainLoss=1.6634  Acc=90.53%
# ✔ Saved STUDENT checkpoint (90.53%)
# convnext_tiny Student | Epoch 8: TrainLoss=1.1182  Acc=91.77%
# ✔ Saved STUDENT checkpoint (91.77%)
# convnext_tiny Student | Epoch 9: TrainLoss=0.8372  Acc=89.51%
# convnext_tiny Student | Epoch 10: TrainLoss=0.7950  Acc=91.15%
# convnext_tiny Student | Epoch 11: TrainLoss=0.3489  Acc=93.21%
# ✔ Saved STUDENT checkpoint (93.21%)
# convnext_tiny Student | Epoch 12: TrainLoss=0.2590  Acc=90.95%
# convnext_tiny Student | Epoch 13: TrainLoss=0.1452  Acc=88.89%
# convnext_tiny Student | Epoch 14: TrainLoss=0.1752  Acc=90.12%
# convnext_tiny Student | Epoch 15: TrainLoss=0.1301  Acc=92.80%
# convnext_tiny Student | Epoch 16: TrainLoss=0.0932  Acc=93.42%
# ✔ Saved STUDENT checkpoint (93.42%)
# convnext_tiny Student | Epoch 17: TrainLoss=0.1244  Acc=91.98%
# convnext_tiny Student | Epoch 18: TrainLoss=0.1293  Acc=90.53%
# convnext_tiny Student | Epoch 19: TrainLoss=0.1193  Acc=89.71%
# convnext_tiny Student | Epoch 20: TrainLoss=0.0978  Acc=92.18%
# convnext_tiny Student | Epoch 21: TrainLoss=0.0653  Acc=93.83%
# ✔ Saved STUDENT checkpoint (93.83%)
# convnext_tiny Student | Epoch 22: TrainLoss=0.0607  Acc=94.24%
# ✔ Saved STUDENT checkpoint (94.24%)
# convnext_tiny Student | Epoch 23: TrainLoss=0.0429  Acc=93.83%
# convnext_tiny Student | Epoch 24: TrainLoss=0.0384  Acc=94.24%
# convnext_tiny Student | Epoch 25: TrainLoss=0.0433  Acc=94.86%
# ✔ Saved STUDENT checkpoint (94.86%)
# convnext_tiny Student | Epoch 26: TrainLoss=0.0354  Acc=94.65%
# convnext_tiny Student | Epoch 27: TrainLoss=0.0340  Acc=94.24%
# convnext_tiny Student | Epoch 28: TrainLoss=0.0299  Acc=93.83%
# convnext_tiny Student | Epoch 29: TrainLoss=0.0331  Acc=93.62%
# convnext_tiny Student | Epoch 30: TrainLoss=0.0299  Acc=93.62%
# convnext_tiny Student | Epoch 31: TrainLoss=0.0269  Acc=93.21%
# convnext_tiny Student | Epoch 32: TrainLoss=0.0263  Acc=93.42%
# convnext_tiny Student | Epoch 33: TrainLoss=0.0242  Acc=93.42%
# convnext_tiny Student | Epoch 34: TrainLoss=0.0246  Acc=93.00%
# convnext_tiny Student | Epoch 35: TrainLoss=0.0223  Acc=92.80%
# convnext_tiny Student | Epoch 36: TrainLoss=0.0215  Acc=92.80%
# convnext_tiny Student | Epoch 37: TrainLoss=0.0201  Acc=92.80%
# convnext_tiny Student | Epoch 38: TrainLoss=0.0205  Acc=92.80%
# convnext_tiny Student | Epoch 39: TrainLoss=0.0185  Acc=93.00%
# convnext_tiny Student | Epoch 40: TrainLoss=0.0166  Acc=93.21%
# convnext_tiny Student | Epoch 41: TrainLoss=0.0173  Acc=92.80%
# convnext_tiny Student | Epoch 42: TrainLoss=0.0178  Acc=92.80%
# convnext_tiny Student | Epoch 43: TrainLoss=0.0172  Acc=93.00%
# convnext_tiny Student | Epoch 44: TrainLoss=0.0166  Acc=93.00%
# convnext_tiny Student | Epoch 45: TrainLoss=0.0169  Acc=93.00%
# convnext_tiny Student | Epoch 46: TrainLoss=0.0157  Acc=93.42%
# convnext_tiny Student | Epoch 47: TrainLoss=0.0152  Acc=93.42%
# convnext_tiny Student | Epoch 48: TrainLoss=0.0144  Acc=93.42%
# convnext_tiny Student | Epoch 49: TrainLoss=0.0152  Acc=93.21%
# convnext_tiny Student | Epoch 50: TrainLoss=0.0151  Acc=93.21%
# convnext_tiny Student | Epoch 51: TrainLoss=0.0146  Acc=93.00%
# convnext_tiny Student | Epoch 52: TrainLoss=0.0157  Acc=93.00%
# convnext_tiny Student | Epoch 53: TrainLoss=0.0133  Acc=93.00%
# convnext_tiny Student | Epoch 54: TrainLoss=0.0144  Acc=93.42%
# convnext_tiny Student | Epoch 55: TrainLoss=0.0133  Acc=93.42%
# ⛔ Early stopping (student)
# 🏁 Finished STUDENT for convnext_tiny. Best Acc=94.86%
#
# ======================================================================
# 🎓 Training STUDENT model with KD: resnet18
# ======================================================================
# resnet18 Student | Epoch 0: TrainLoss=8.7728  Acc=68.93%
# ✔ Saved STUDENT checkpoint (68.93%)
# resnet18 Student | Epoch 1: TrainLoss=2.2133  Acc=77.16%
# ✔ Saved STUDENT checkpoint (77.16%)
# resnet18 Student | Epoch 2: TrainLoss=0.7903  Acc=74.90%
# resnet18 Student | Epoch 3: TrainLoss=0.4248  Acc=77.98%
# ✔ Saved STUDENT checkpoint (77.98%)
# resnet18 Student | Epoch 4: TrainLoss=0.3653  Acc=84.57%
# ✔ Saved STUDENT checkpoint (84.57%)
# resnet18 Student | Epoch 5: TrainLoss=0.2791  Acc=82.92%
# resnet18 Student | Epoch 6: TrainLoss=0.2995  Acc=83.95%
# resnet18 Student | Epoch 7: TrainLoss=0.2536  Acc=86.83%
# ✔ Saved STUDENT checkpoint (86.83%)
# resnet18 Student | Epoch 8: TrainLoss=0.2051  Acc=90.12%
# ✔ Saved STUDENT checkpoint (90.12%)
# resnet18 Student | Epoch 9: TrainLoss=0.1704  Acc=91.56%
# ✔ Saved STUDENT checkpoint (91.56%)
# resnet18 Student | Epoch 10: TrainLoss=0.1480  Acc=91.15%
# resnet18 Student | Epoch 11: TrainLoss=0.1619  Acc=90.74%
# resnet18 Student | Epoch 12: TrainLoss=0.1058  Acc=91.56%
# resnet18 Student | Epoch 13: TrainLoss=0.0832  Acc=91.36%
# resnet18 Student | Epoch 14: TrainLoss=0.0934  Acc=89.30%
# resnet18 Student | Epoch 15: TrainLoss=0.0956  Acc=89.30%
# resnet18 Student | Epoch 16: TrainLoss=0.0607  Acc=90.74%
# resnet18 Student | Epoch 17: TrainLoss=0.0565  Acc=92.18%
# ✔ Saved STUDENT checkpoint (92.18%)
# resnet18 Student | Epoch 18: TrainLoss=0.0563  Acc=92.80%
# ✔ Saved STUDENT checkpoint (92.80%)
# ...
# ✔ Saved STUDENT checkpoint (91.56%)
# efficientnet_b0 Student | Epoch 7: TrainLoss=0.4114  Acc=91.36%
# efficientnet_b0 Student | Epoch 8: TrainLoss=0.3647  Acc=91.15%
# efficientnet_b0 Student | Epoch 9: TrainLoss=0.2994  Acc=91.36%
# efficientnet_b0 Student | Epoch 10: TrainLoss=0.2500  Acc=91.15%
# efficientnet_b0 Student | Epoch 11: TrainLoss=0.1870  Acc=92.80%
# ✔ Saved STUDENT checkpoint (92.80%)
# efficientnet_b0 Student | Epoch 12: TrainLoss=0.1523  Acc=93.42%
# ✔ Saved STUDENT checkpoint (93.42%)
# efficientnet_b0 Student | Epoch 13: TrainLoss=0.2034  Acc=93.83%
# ✔ Saved STUDENT checkpoint (93.83%)
# efficientnet_b0 Student | Epoch 14: TrainLoss=0.1410  Acc=94.86%
# ✔ Saved STUDENT checkpoint (94.86%)
# efficientnet_b0 Student | Epoch 15: TrainLoss=0.1634  Acc=95.06%
# ✔ Saved STUDENT checkpoint (95.06%)
# efficientnet_b0 Student | Epoch 16: TrainLoss=0.1570  Acc=94.86%
# efficientnet_b0 Student | Epoch 17: TrainLoss=0.1290  Acc=94.65%
# efficientnet_b0 Student | Epoch 18: TrainLoss=0.0844  Acc=94.44%
# efficientnet_b0 Student | Epoch 19: TrainLoss=0.1068  Acc=94.03%
# efficientnet_b0 Student | Epoch 20: TrainLoss=0.1042  Acc=94.24%
# efficientnet_b0 Student | Epoch 21: TrainLoss=0.1043  Acc=94.44%
# efficientnet_b0 Student | Epoch 22: TrainLoss=0.0805  Acc=95.06%
# efficientnet_b0 Student | Epoch 23: TrainLoss=0.0789  Acc=95.06%
# efficientnet_b0 Student | Epoch 24: TrainLoss=0.1250  Acc=94.86%
# efficientnet_b0 Student | Epoch 25: TrainLoss=0.0580  Acc=95.06%
# efficientnet_b0 Student | Epoch 26: TrainLoss=0.1045  Acc=94.86%
# efficientnet_b0 Student | Epoch 27: TrainLoss=0.0611  Acc=94.44%
# efficientnet_b0 Student | Epoch 28: TrainLoss=0.0523  Acc=94.44%
# efficientnet_b0 Student | Epoch 29: TrainLoss=0.0635  Acc=94.44%
# efficientnet_b0 Student | Epoch 30: TrainLoss=0.0546  Acc=94.44%
# efficientnet_b0 Student | Epoch 31: TrainLoss=0.0740  Acc=94.44%
# efficientnet_b0 Student | Epoch 32: TrainLoss=0.0538  Acc=94.44%
# efficientnet_b0 Student | Epoch 33: TrainLoss=0.0639  Acc=94.65%
# efficientnet_b0 Student | Epoch 34: TrainLoss=0.0934  Acc=94.86%
# efficientnet_b0 Student | Epoch 35: TrainLoss=0.0712  Acc=94.86%
# efficientnet_b0 Student | Epoch 36: TrainLoss=0.0527  Acc=94.86%
# efficientnet_b0 Student | Epoch 37: TrainLoss=0.0485  Acc=94.86%
# efficientnet_b0 Student | Epoch 38: TrainLoss=0.0766  Acc=94.86%
# efficientnet_b0 Student | Epoch 39: TrainLoss=0.0607  Acc=94.86%
# efficientnet_b0 Student | Epoch 40: TrainLoss=0.0589  Acc=95.06%
# efficientnet_b0 Student | Epoch 41: TrainLoss=0.0544  Acc=94.86%
# efficientnet_b0 Student | Epoch 42: TrainLoss=0.0356  Acc=94.86%
# efficientnet_b0 Student | Epoch 43: TrainLoss=0.0618  Acc=94.86%
# efficientnet_b0 Student | Epoch 44: TrainLoss=0.0356  Acc=94.86%
# efficientnet_b0 Student | Epoch 45: TrainLoss=0.0414  Acc=94.86%
# ⛔ Early stopping (student)
# 🏁 Finished STUDENT for efficientnet_b0. Best Acc=95.06%
#
# ======================================================================
# 🎓 Training STUDENT model with KD: mobilenet_v2
# ======================================================================
# mobilenet_v2 Student | Epoch 0: TrainLoss=9.8743  Acc=35.60%
# ✔ Saved STUDENT checkpoint (35.60%)
# mobilenet_v2 Student | Epoch 1: TrainLoss=3.8226  Acc=60.70%
# ✔ Saved STUDENT checkpoint (60.70%)
# mobilenet_v2 Student | Epoch 2: TrainLoss=1.3354  Acc=71.19%
# ✔ Saved STUDENT checkpoint (71.19%)
# mobilenet_v2 Student | Epoch 3: TrainLoss=0.5752  Acc=87.04%
# ✔ Saved STUDENT checkpoint (87.04%)
# mobilenet_v2 Student | Epoch 4: TrainLoss=0.4495  Acc=89.71%
# ✔ Saved STUDENT checkpoint (89.71%)
# mobilenet_v2 Student | Epoch 5: TrainLoss=0.3135  Acc=92.39%
# ✔ Saved STUDENT checkpoint (92.39%)
# mobilenet_v2 Student | Epoch 6: TrainLoss=0.2644  Acc=92.80%
# ✔ Saved STUDENT checkpoint (92.80%)
# mobilenet_v2 Student | Epoch 7: TrainLoss=0.2775  Acc=93.83%
# ✔ Saved STUDENT checkpoint (93.83%)
# mobilenet_v2 Student | Epoch 8: TrainLoss=0.1899  Acc=92.80%
# mobilenet_v2 Student | Epoch 9: TrainLoss=0.2068  Acc=92.80%
# mobilenet_v2 Student | Epoch 10: TrainLoss=0.2296  Acc=92.80%
# mobilenet_v2 Student | Epoch 11: TrainLoss=0.1651  Acc=92.18%
# mobilenet_v2 Student | Epoch 12: TrainLoss=0.1525  Acc=92.59%
# mobilenet_v2 Student | Epoch 13: TrainLoss=0.1278  Acc=94.44%
# ✔ Saved STUDENT checkpoint (94.44%)
# mobilenet_v2 Student | Epoch 14: TrainLoss=0.1136  Acc=94.03%
# mobilenet_v2 Student | Epoch 15: TrainLoss=0.1031  Acc=94.86%
# ✔ Saved STUDENT checkpoint (94.86%)
# mobilenet_v2 Student | Epoch 16: TrainLoss=0.1481  Acc=94.86%
# mobilenet_v2 Student | Epoch 17: TrainLoss=0.1125  Acc=95.06%
# ✔ Saved STUDENT checkpoint (95.06%)
# mobilenet_v2 Student | Epoch 18: TrainLoss=0.1279  Acc=95.68%
# ✔ Saved STUDENT checkpoint (95.68%)
# mobilenet_v2 Student | Epoch 19: TrainLoss=0.0696  Acc=95.68%
# mobilenet_v2 Student | Epoch 20: TrainLoss=0.0777  Acc=95.27%
# mobilenet_v2 Student | Epoch 21: TrainLoss=0.0965  Acc=95.27%
# mobilenet_v2 Student | Epoch 22: TrainLoss=0.0546  Acc=95.06%
# mobilenet_v2 Student | Epoch 23: TrainLoss=0.0674  Acc=94.44%
# mobilenet_v2 Student | Epoch 24: TrainLoss=0.0498  Acc=94.24%
# mobilenet_v2 Student | Epoch 25: TrainLoss=0.0473  Acc=94.03%
# mobilenet_v2 Student | Epoch 26: TrainLoss=0.0394  Acc=94.03%
# mobilenet_v2 Student | Epoch 27: TrainLoss=0.0453  Acc=93.83%
# mobilenet_v2 Student | Epoch 28: TrainLoss=0.0715  Acc=93.83%
# mobilenet_v2 Student | Epoch 29: TrainLoss=0.0723  Acc=93.83%
# mobilenet_v2 Student | Epoch 30: TrainLoss=0.0603  Acc=93.83%
# mobilenet_v2 Student | Epoch 31: TrainLoss=0.0422  Acc=93.83%
# mobilenet_v2 Student | Epoch 32: TrainLoss=0.0651  Acc=93.83%
# mobilenet_v2 Student | Epoch 33: TrainLoss=0.0559  Acc=93.83%
# mobilenet_v2 Student | Epoch 34: TrainLoss=0.0667  Acc=93.83%
# mobilenet_v2 Student | Epoch 35: TrainLoss=0.0482  Acc=94.03%
# mobilenet_v2 Student | Epoch 36: TrainLoss=0.0393  Acc=94.03%
# mobilenet_v2 Student | Epoch 37: TrainLoss=0.0454  Acc=94.24%
# mobilenet_v2 Student | Epoch 38: TrainLoss=0.0407  Acc=94.24%
# mobilenet_v2 Student | Epoch 39: TrainLoss=0.0584  Acc=94.03%
# mobilenet_v2 Student | Epoch 40: TrainLoss=0.0407  Acc=94.03%
# mobilenet_v2 Student | Epoch 41: TrainLoss=0.0365  Acc=94.24%
# mobilenet_v2 Student | Epoch 42: TrainLoss=0.0293  Acc=94.03%
# mobilenet_v2 Student | Epoch 43: TrainLoss=0.0360  Acc=94.03%
# mobilenet_v2 Student | Epoch 44: TrainLoss=0.0527  Acc=94.44%
# mobilenet_v2 Student | Epoch 45: TrainLoss=0.0403  Acc=94.44%
# mobilenet_v2 Student | Epoch 46: TrainLoss=0.0333  Acc=94.44%
# mobilenet_v2 Student | Epoch 47: TrainLoss=0.0462  Acc=94.24%
# mobilenet_v2 Student | Epoch 48: TrainLoss=0.0376  Acc=94.24%
# ⛔ Early stopping (student)
# 🏁 Finished STUDENT for mobilenet_v2. Best Acc=95.68%
#
# ======================================================================
# 🎓 Training STUDENT model with KD: mobilenetv3_small
# ======================================================================
# mobilenetv3_small Student | Epoch 0: TrainLoss=12.9038  Acc=58.85%
# ✔ Saved STUDENT checkpoint (58.85%)
# mobilenetv3_small Student | Epoch 1: TrainLoss=8.6041  Acc=59.88%
# ✔ Saved STUDENT checkpoint (59.88%)
# mobilenetv3_small Student | Epoch 2: TrainLoss=5.4675  Acc=57.61%
# mobilenetv3_small Student | Epoch 3: TrainLoss=3.3014  Acc=58.23%
# mobilenetv3_small Student | Epoch 4: TrainLoss=1.9353  Acc=58.02%
# mobilenetv3_small Student | Epoch 5: TrainLoss=1.1350  Acc=56.38%
# mobilenetv3_small Student | Epoch 6: TrainLoss=0.7666  Acc=53.09%
# mobilenetv3_small Student | Epoch 7: TrainLoss=0.6327  Acc=52.47%
# mobilenetv3_small Student | Epoch 8: TrainLoss=0.5806  Acc=52.67%
# mobilenetv3_small Student | Epoch 9: TrainLoss=0.4157  Acc=51.65%
# mobilenetv3_small Student | Epoch 10: TrainLoss=0.4008  Acc=50.00%
# mobilenetv3_small Student | Epoch 11: TrainLoss=0.3843  Acc=49.38%
# mobilenetv3_small Student | Epoch 12: TrainLoss=0.3512  Acc=48.35%
# mobilenetv3_small Student | Epoch 13: TrainLoss=0.2796  Acc=48.35%
# mobilenetv3_small Student | Epoch 14: TrainLoss=0.3041  Acc=48.15%
# mobilenetv3_small Student | Epoch 15: TrainLoss=0.2229  Acc=48.35%
# mobilenetv3_small Student | Epoch 16: TrainLoss=0.2049  Acc=49.59%
# mobilenetv3_small Student | Epoch 17: TrainLoss=0.1681  Acc=50.21%
# mobilenetv3_small Student | Epoch 18: TrainLoss=0.1570  Acc=50.41%
# mobilenetv3_small Student | Epoch 19: TrainLoss=0.1534  Acc=50.21%
# mobilenetv3_small Student | Epoch 20: TrainLoss=0.1339  Acc=50.62%
# mobilenetv3_small Student | Epoch 21: TrainLoss=0.1316  Acc=50.62%
# mobilenetv3_small Student | Epoch 22: TrainLoss=0.1208  Acc=51.23%
# mobilenetv3_small Student | Epoch 23: TrainLoss=0.1300  Acc=52.06%
# mobilenetv3_small Student | Epoch 24: TrainLoss=0.1023  Acc=52.47%
# mobilenetv3_small Student | Epoch 25: TrainLoss=0.1159  Acc=52.67%
# mobilenetv3_small Student | Epoch 26: TrainLoss=0.1111  Acc=53.50%
# mobilenetv3_small Student | Epoch 27: TrainLoss=0.0869  Acc=54.53%
# mobilenetv3_small Student | Epoch 28: TrainLoss=0.0933  Acc=55.35%
# mobilenetv3_small Student | Epoch 29: TrainLoss=0.0920  Acc=55.76%
# mobilenetv3_small Student | Epoch 30: TrainLoss=0.0983  Acc=56.38%
# mobilenetv3_small Student | Epoch 31: TrainLoss=0.1378  Acc=56.79%
# ⛔ Early stopping (student)
# 🏁 Finished STUDENT for mobilenetv3_small. Best Acc=59.88%
#
# ======================================================================
# 🎓 Training STUDENT model with KD: tinycnn
# ======================================================================
# tinycnn Student | Epoch 0: TrainLoss=5.0688  Acc=15.84%
# ✔ Saved STUDENT checkpoint (15.84%)
# tinycnn Student | Epoch 1: TrainLoss=4.1469  Acc=15.84%
# tinycnn Student | Epoch 2: TrainLoss=3.5039  Acc=25.31%
# ✔ Saved STUDENT checkpoint (25.31%)
# tinycnn Student | Epoch 3: TrainLoss=3.0281  Acc=8.23%
# tinycnn Student | Epoch 4: TrainLoss=2.6900  Acc=8.23%
# tinycnn Student | Epoch 5: TrainLoss=2.3637  Acc=8.23%
# tinycnn Student | Epoch 6: TrainLoss=2.1229  Acc=8.23%
# tinycnn Student | Epoch 7: TrainLoss=1.9574  Acc=8.23%
# tinycnn Student | Epoch 8: TrainLoss=1.7915  Acc=8.23%
# tinycnn Student | Epoch 9: TrainLoss=1.6244  Acc=8.23%
# tinycnn Student | Epoch 10: TrainLoss=1.4777  Acc=8.23%
# tinycnn Student | Epoch 11: TrainLoss=1.3429  Acc=8.23%
# tinycnn Student | Epoch 12: TrainLoss=1.2260  Acc=10.49%
# tinycnn Student | Epoch 13: TrainLoss=1.1023  Acc=15.02%
# tinycnn Student | Epoch 14: TrainLoss=0.9912  Acc=18.11%
# tinycnn Student | Epoch 15: TrainLoss=0.8820  Acc=20.58%
# tinycnn Student | Epoch 16: TrainLoss=0.8201  Acc=21.81%
# tinycnn Student | Epoch 17: TrainLoss=0.7260  Acc=23.66%
# tinycnn Student | Epoch 18: TrainLoss=0.7469  Acc=28.81%
# ✔ Saved STUDENT checkpoint (28.81%)
# tinycnn Student | Epoch 19: TrainLoss=0.6281  Acc=37.24%
# ✔ Saved STUDENT checkpoint (37.24%)
# tinycnn Student | Epoch 20: TrainLoss=0.5782  Acc=47.12%
# ✔ Saved STUDENT checkpoint (47.12%)
# tinycnn Student | Epoch 21: TrainLoss=0.5813  Acc=56.17%
# ✔ Saved STUDENT checkpoint (56.17%)
# tinycnn Student | Epoch 22: TrainLoss=0.5315  Acc=63.37%
# ✔ Saved STUDENT checkpoint (63.37%)
# tinycnn Student | Epoch 23: TrainLoss=0.5130  Acc=70.78%
# ✔ Saved STUDENT checkpoint (70.78%)
# tinycnn Student | Epoch 24: TrainLoss=0.4763  Acc=74.90%
# ✔ Saved STUDENT checkpoint (74.90%)
# tinycnn Student | Epoch 25: TrainLoss=0.4826  Acc=77.78%
# ✔ Saved STUDENT checkpoint (77.78%)
# tinycnn Student | Epoch 26: TrainLoss=0.4780  Acc=79.42%
# ✔ Saved STUDENT checkpoint (79.42%)
# tinycnn Student | Epoch 27: TrainLoss=0.4347  Acc=81.07%
# ✔ Saved STUDENT checkpoint (81.07%)
# tinycnn Student | Epoch 28: TrainLoss=0.4473  Acc=81.48%
# ✔ Saved STUDENT checkpoint (81.48%)
# tinycnn Student | Epoch 29: TrainLoss=0.3991  Acc=81.69%
# ✔ Saved STUDENT checkpoint (81.69%)
# tinycnn Student | Epoch 30: TrainLoss=0.3909  Acc=81.48%
# tinycnn Student | Epoch 31: TrainLoss=0.3661  Acc=82.30%
# ✔ Saved STUDENT checkpoint (82.30%)
# tinycnn Student | Epoch 32: TrainLoss=0.3989  Acc=82.72%
# ✔ Saved STUDENT checkpoint (82.72%)
# tinycnn Student | Epoch 33: TrainLoss=0.3565  Acc=83.74%
# ✔ Saved STUDENT checkpoint (83.74%)
# tinycnn Student | Epoch 34: TrainLoss=0.3522  Acc=83.54%
# tinycnn Student | Epoch 35: TrainLoss=0.3225  Acc=83.33%
# tinycnn Student | Epoch 36: TrainLoss=0.3253  Acc=82.51%
# tinycnn Student | Epoch 37: TrainLoss=0.3016  Acc=82.72%
# tinycnn Student | Epoch 38: TrainLoss=0.3032  Acc=82.92%
# tinycnn Student | Epoch 39: TrainLoss=0.2924  Acc=83.95%
# ✔ Saved STUDENT checkpoint (83.95%)
# tinycnn Student | Epoch 40: TrainLoss=0.2836  Acc=84.98%
# ✔ Saved STUDENT checkpoint (84.98%)
# tinycnn Student | Epoch 41: TrainLoss=0.2791  Acc=84.57%
# tinycnn Student | Epoch 42: TrainLoss=0.2928  Acc=84.77%
# tinycnn Student | Epoch 43: TrainLoss=0.2741  Acc=83.95%
# tinycnn Student | Epoch 44: TrainLoss=0.2629  Acc=84.16%
# tinycnn Student | Epoch 45: TrainLoss=0.2415  Acc=84.77%
# tinycnn Student | Epoch 46: TrainLoss=0.2648  Acc=85.19%
# ✔ Saved STUDENT checkpoint (85.19%)
# tinycnn Student | Epoch 47: TrainLoss=0.2346  Acc=85.39%
# ✔ Saved STUDENT checkpoint (85.39%)
# tinycnn Student | Epoch 48: TrainLoss=0.2524  Acc=85.60%
# ✔ Saved STUDENT checkpoint (85.60%)
# tinycnn Student | Epoch 49: TrainLoss=0.2565  Acc=86.01%
# ✔ Saved STUDENT checkpoint (86.01%)
# tinycnn Student | Epoch 50: TrainLoss=0.2316  Acc=85.19%
# tinycnn Student | Epoch 51: TrainLoss=0.2609  Acc=85.60%
# tinycnn Student | Epoch 52: TrainLoss=0.2678  Acc=85.60%
# tinycnn Student | Epoch 53: TrainLoss=0.2453  Acc=85.39%
# tinycnn Student | Epoch 54: TrainLoss=0.2296  Acc=86.01%
# tinycnn Student | Epoch 55: TrainLoss=0.2188  Acc=85.80%
# tinycnn Student | Epoch 56: TrainLoss=0.2338  Acc=86.01%
# tinycnn Student | Epoch 57: TrainLoss=0.2132  Acc=86.01%
# tinycnn Student | Epoch 58: TrainLoss=0.2367  Acc=86.42%
# ✔ Saved STUDENT checkpoint (86.42%)
# tinycnn Student | Epoch 59: TrainLoss=0.2116  Acc=86.63%
# ✔ Saved STUDENT checkpoint (86.63%)
# tinycnn Student | Epoch 60: TrainLoss=0.2110  Acc=86.63%
# tinycnn Student | Epoch 61: TrainLoss=0.2158  Acc=86.42%
# tinycnn Student | Epoch 62: TrainLoss=0.2091  Acc=86.21%
# tinycnn Student | Epoch 63: TrainLoss=0.2102  Acc=86.42%
# tinycnn Student | Epoch 64: TrainLoss=0.1960  Acc=86.21%
# tinycnn Student | Epoch 65: TrainLoss=0.1947  Acc=86.42%
# tinycnn Student | Epoch 66: TrainLoss=0.2239  Acc=86.42%
# tinycnn Student | Epoch 67: TrainLoss=0.1960  Acc=86.42%
# tinycnn Student | Epoch 68: TrainLoss=0.1887  Acc=86.42%
# tinycnn Student | Epoch 69: TrainLoss=0.1964  Acc=86.42%
# tinycnn Student | Epoch 70: TrainLoss=0.1864  Acc=86.42%
# tinycnn Student | Epoch 71: TrainLoss=0.1841  Acc=86.21%
# tinycnn Student | Epoch 72: TrainLoss=0.2070  Acc=86.63%
# tinycnn Student | Epoch 73: TrainLoss=0.1981  Acc=87.04%
# ✔ Saved STUDENT checkpoint (87.04%)
# tinycnn Student | Epoch 74: TrainLoss=0.2051  Acc=86.83%
# tinycnn Student | Epoch 75: TrainLoss=0.1740  Acc=87.24%
# ✔ Saved STUDENT checkpoint (87.24%)
# tinycnn Student | Epoch 76: TrainLoss=0.1894  Acc=86.42%
# tinycnn Student | Epoch 77: TrainLoss=0.1851  Acc=86.42%
# tinycnn Student | Epoch 78: TrainLoss=0.1983  Acc=86.21%
# tinycnn Student | Epoch 79: TrainLoss=0.1798  Acc=86.83%
# tinycnn Student | Epoch 80: TrainLoss=0.1812  Acc=86.63%
# tinycnn Student | Epoch 81: TrainLoss=0.1927  Acc=86.63%
# tinycnn Student | Epoch 82: TrainLoss=0.1783  Acc=86.63%
# tinycnn Student | Epoch 83: TrainLoss=0.1794  Acc=86.83%
# tinycnn Student | Epoch 84: TrainLoss=0.1937  Acc=87.04%
# tinycnn Student | Epoch 85: TrainLoss=0.1771  Acc=86.83%
# tinycnn Student | Epoch 86: TrainLoss=0.1904  Acc=86.83%
# tinycnn Student | Epoch 87: TrainLoss=0.1792  Acc=87.04%
# tinycnn Student | Epoch 88: TrainLoss=0.1678  Acc=86.42%
# tinycnn Student | Epoch 89: TrainLoss=0.1796  Acc=86.83%
# tinycnn Student | Epoch 90: TrainLoss=0.1803  Acc=87.04%
# tinycnn Student | Epoch 91: TrainLoss=0.1787  Acc=86.83%
# tinycnn Student | Epoch 92: TrainLoss=0.1817  Acc=86.83%
# tinycnn Student | Epoch 93: TrainLoss=0.1870  Acc=86.63%
# tinycnn Student | Epoch 94: TrainLoss=0.1781  Acc=86.83%
# tinycnn Student | Epoch 95: TrainLoss=0.1743  Acc=86.83%
# tinycnn Student | Epoch 96: TrainLoss=0.2091  Acc=86.83%
# tinycnn Student | Epoch 97: TrainLoss=0.1863  Acc=87.04%
# tinycnn Student | Epoch 98: TrainLoss=0.1759  Acc=87.04%
# tinycnn Student | Epoch 99: TrainLoss=0.1811  Acc=87.04%
# 🏁 Finished STUDENT for tinycnn. Best Acc=87.24%
#
# 🎉 All teacher–student KD training done!
